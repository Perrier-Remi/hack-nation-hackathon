# %%
import os
import cv2
import torch
import numpy as np
import json
import supervision as sv
from PIL import Image
from sam2.build_sam import build_sam2_video_predictor, build_sam2
from sam2.sam2_image_predictor import SAM2ImagePredictor
from transformers import AutoProcessor, AutoModelForZeroShotObjectDetection 
import cv2
import numpy as np
import io
from google import genai
from google.genai.types import Part
from dotenv import load_dotenv


load_dotenv()



class GroundedSam2Tracker:
    """
    A unified class to handle video segmentation, Grounding DINO detection, 
    and SAM 2 video tracking for a hackathon project.
    """
    def __init__(self, sam2_checkpoint_path, sam2_config_file, gdino_model_id="IDEA-Research/grounding-dino-tiny"):
        
        # --- Efficiency Setup (Hackathon Tip: Load once!) ---
        torch.cuda.empty_cache()
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        
        # Enable performance features for newer GPUs
        if torch.cuda.get_device_properties(0).major >= 8:
            torch.backends.cuda.matmul.allow_tf32 = True
            torch.backends.cudnn.allow_tf32 = True
            
        # Initialize SAM 2 image and video predictors
        self.video_predictor = build_sam2_video_predictor(sam2_config_file, sam2_checkpoint_path)
        sam2_image_model = build_sam2(sam2_config_file, sam2_checkpoint_path)
        self.image_predictor = SAM2ImagePredictor(sam2_image_model)

        # Initialize Grounding DINO
        self.gdino_processor = AutoProcessor.from_pretrained(gdino_model_id)
        self.gdino_model = AutoModelForZeroShotObjectDetection.from_pretrained(gdino_model_id).to(self.device)
        print("✅ Models initialized and moved to CUDA.")


    def segment_video(self, video_path, output_folder_frames, target_resolution=(960, 540), max_images=400):
        """
        [PHASE 1] Extract frames from a video, skipping frames to respect max_images limit.
        Stores output folder path for subsequent tracking.
        """
        self.video_path = video_path
        self.output_folder_frames = output_folder_frames
        
        if not os.path.exists(output_folder_frames):
            os.makedirs(output_folder_frames)
        
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            print(f"Error: Unable to open video at {video_path}")
            return False

        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        frames_per_image = int(np.ceil(total_frames / max_images)) if total_frames > max_images else 1

        print(f"Total frames: {total_frames}. Calculated interval: {frames_per_image}")
        
        frame_count = 0
        image_count = 0
        while True:
            ret, frame = cap.read()
            if not ret: break
            
            if frame_count % frames_per_image == 0 and image_count < max_images:
                resized_frame = cv2.resize(frame, target_resolution, interpolation=cv2.INTER_AREA)
                output_filename = os.path.join(output_folder_frames, f"{image_count:03d}.jpg")
                cv2.imwrite(output_filename, resized_frame)
                image_count += 1
            
            if image_count >= max_images: break
            frame_count += 1
            
        cap.release()
        print(f"Extraction finished. {image_count} frames saved.")
        return True


    def track_object(self, prompt, initial_frame_idx=0):
        """
        [PHASE 2] Track and segment the object defined by 'prompt' across all frames.
        Returns a list of annotated (NumPy array) frames.
        """
        
        # --- Setup paths and state ---
        video_dir = self.output_folder_frames
        
        frame_names = [p for p in os.listdir(video_dir)
                       if os.path.splitext(p)[-1] in [".jpg", ".jpeg", ".JPG", ".JPEG"]]
        frame_names.sort(key=lambda p: int(os.path.splitext(p)[0]))
        
        if not frame_names:
            print("Error: No frames found in the directory.")
            return []

        # Use bfloat16 for computation
        with torch.autocast(device_type="cuda", dtype=torch.bfloat16):
            
            # --- Step 2: Initial Grounding DINO Detection (on the first frame) ---
            img_path = os.path.join(video_dir, frame_names[initial_frame_idx])
            image = Image.open(img_path)

            inputs = self.gdino_processor(images=image, text=prompt, return_tensors="pt").to(self.device)
            with torch.no_grad():
                outputs = self.gdino_model(**inputs)

            results = self.gdino_processor.post_process_grounded_object_detection(
                outputs,
                inputs.input_ids,
                threshold=0.25,
                text_threshold=0.3,
                target_sizes=[image.size[::-1]]
            )
            
            # --- Step 2b: SAM 2 Image Segmentation (on the first frame) ---
            self.image_predictor.set_image(np.array(image.convert("RGB")))
            
            input_boxes = results[0]["boxes"].cpu().numpy()
            OBJECTS = results[0]["labels"]

            masks, _, _ = self.image_predictor.predict(box=input_boxes, multimask_output=False)
            
            if masks.ndim == 4: masks = masks.squeeze(1)

            # --- Step 3: Register Prompts to Video Predictor ---
            inference_state = self.video_predictor.init_state(video_path=video_dir)
            PROMPT_TYPE_FOR_VIDEO = "box" 
            
            for object_id, (box) in enumerate(input_boxes, start=1):
                self.video_predictor.add_new_points_or_box(
                    inference_state=inference_state,
                    frame_idx=initial_frame_idx,
                    obj_id=object_id,
                    box=box,
                )

            # --- Step 4: Propagate Masks through all frames ---
            video_segments = {}
            print(f"Starting tracking from frame {initial_frame_idx} for '{prompt}'.")
            
            for out_frame_idx, out_obj_ids, out_mask_logits in self.video_predictor.propagate_in_video(inference_state):
                video_segments[out_frame_idx] = {
                    out_obj_id: (out_mask_logits[i] > 0.0).cpu().numpy()
                    for i, out_obj_id in enumerate(out_obj_ids)
                }

        # --- Step 5: Annotate and Collect Results ---
        annotated_frames_list = []
        ID_TO_OBJECTS = {i: obj for i, obj in enumerate(OBJECTS, start=1)}
        
        for frame_idx, segments in video_segments.items():
            img = cv2.imread(os.path.join(video_dir, frame_names[frame_idx]))
            if img is None: continue

            object_ids = list(segments.keys())
            masks = list(segments.values())
            masks = np.concatenate(masks, axis=0)

            detections = sv.Detections(
                xyxy=sv.mask_to_xyxy(masks),
                mask=masks,
                class_id=np.array(object_ids, dtype=np.int32),
            )
            
            # Annotate
            box_annotator = sv.BoxAnnotator()
            annotated_frame = box_annotator.annotate(scene=img.copy(), detections=detections)
            label_annotator = sv.LabelAnnotator()
            annotated_frame = label_annotator.annotate(annotated_frame, detections=detections, 
                labels=[ID_TO_OBJECTS.get(i, "tracked object") for i in object_ids])
            mask_annotator = sv.MaskAnnotator()
            annotated_frame = mask_annotator.annotate(scene=annotated_frame, detections=detections)                
            
            annotated_frames_list.append(annotated_frame)

        print(f"Tracking completed. {len(annotated_frames_list)} frames with tracked objects stored.")
        return annotated_frames_list


# --- MAIN EXECUTION BLOCK (HACKATHON EXAMPLE) ---

# --- CONFIGURATION (Change these paths!) ---
VIDEO_INPUT_PATH = "/home/pepito/Documents/Python/ML/Mit_hackathon/Nike.mp4" 
FRAMES_OUTPUT_DIR = "/home/pepito/Documents/Python/ML/Mit_hackathon/Nike_frames"
SAM2_CHECKPOINT = "/home/pepito/Documents/Python/ML/Mit_hackathon/Grounded-SAM-2/checkpoints/sam2.1_hiera_tiny.pt"
MODEL_CONFIG = "configs/sam2.1/sam2.1_hiera_t.yaml"
TRACKING_PROMPT = "Only sport shoes."
MAX_FRAMES_TO_EXTRACT = 200 # Faster analysis for the hackathon

# 1. Initialize the tracker (Loads models ONCE)
tracker = GroundedSam2Tracker(
    sam2_checkpoint_path=SAM2_CHECKPOINT,
    sam2_config_file=MODEL_CONFIG
)

# 2. Extract frames
tracker.segment_video(
    video_path=VIDEO_INPUT_PATH,
    output_folder_frames=FRAMES_OUTPUT_DIR,
    max_images=MAX_FRAMES_TO_EXTRACT
)

# 3. Track object and get annotated frames list
final_annotated_frames = tracker.track_object(
    prompt=TRACKING_PROMPT
)

# --- Next Steps for Analysis ---
if final_annotated_frames:
    print(f"\nReady for Analysis! The list 'final_annotated_frames' contains {len(final_annotated_frames)} NumPy arrays.")
# Out:
# 2025-11-09 13:06:29.421037: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-09 13:06:29.461167: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-09 13:06:30.739444: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
# ✅ Models initialized and moved to CUDA.
# Total frames: 919. Calculated interval: 5
# Extraction finished. 184 frames saved.
# frame loading (JPEG): 100%|██████████| 307/307 [00:04<00:00, 62.88it/s]
# UserWarning: cannot import name '_C' from 'sam2' (/home/pepito/Documents/Python/ML/Mit_hackathon/Grounded-SAM-2/sam2/__init__.py)
#
# Skipping the post-processing step due to the error above. You can still use SAM 2 and it's OK to ignore the error above, although some post-processing functionality may be limited (which doesn't affect the results in most cases; see https://github.com/facebookresearch/sam2/blob/main/INSTALL.md).
# Starting tracking from frame 0 for 'Only sport shoes.'.
# propagate in video: 100%|██████████| 307/307 [00:30<00:00,  9.91it/s]
# Tracking completed. 307 frames with tracked objects stored.
#
# Ready for Analysis! The list 'final_annotated_frames' contains 307 NumPy arrays.

# %%
import io
import json
import os
import re
import cv2
import numpy as np
from google import genai
from google.genai.types import Part
from dotenv import load_dotenv
from concurrent.futures import ThreadPoolExecutor, as_completed

# --- 1. CONFIGURATION ---
load_dotenv()
try:
    gemini_client = genai.Client()
except Exception as e:
    print(f"Error initializing Gemini client: {e}")

# IMPORTANT: Define brand profiles
BRAND_PROFILES = {
    "Nike": {
        "visual_tone": "Energetic, Dynamic, Performance-focused, High contrast.",
        "flagging_criteria": {"logo_score_min": 0.5, "quality_score_min": 2}
    },
    "Rolex": {
        "visual_tone": "Luxurious, Classic, Minimalist, Elegant lighting.",
        "flagging_criteria": {"logo_score_min": 0.7, "quality_score_min": 4} 
    },
}

# --- 2. PROMPT GENERATION ---
def get_json_template_string():
    """Returns the raw JSON structure as a string with placeholders."""
    return """
    {
      "prompt_id": "BRAND_COHERENCE_V1",
      "target_brand": "{target_brand_name}",
      "frame_status": "OK",
      "metrics": {
        "logo_presence_score": {
          "query": "Is the '{target_brand_name}' logo clearly visible, not obscured, and recognizable in the frame?",
          "score": "[Note between 0.0 (Absent) and 1.0 (Perfect)]",
          "status": "[YES/NO/PARTIAL]"
        },
        "visual_quality_score": {
          "query": "Evaluate the visual quality of the product focus area: clarity, sharpness, and acceptable lighting.",
          "score": "[Note from 1 (Very Poor) to 5 (Excellent)]",
          "justification": "[Describe the visual quality or defect.]"
        },
        "brand_tone_match": {
          "query": "Does the overall mood, composition, and color grading of the frame match the required brand tone: '{brand_visual_tone}'?",
          "match": "[YES/NO]",
          "justification": "[Indicate if the ambiance is coherent with the brand or describe the mismatch.]"
        },
        "product_placement_relevance": {
          "query": "Is the product placed in a context relevant to the brand's identity?",
          "match": "[YES/NO]",
          "justification": "[Describe the product context relevance.]"
        }
      },
      "is_flagged_bad_frame": "[NO]",
      "flag_reason": "None",
      "final_summary": "[One sentence summarizing conformity and the main positive/negative point.]"
    }
    """

def get_single_frame_prompt_custom(target_brand_name):
    """Generates the customized prompt containing the JSON template."""
    
    profile = BRAND_PROFILES.get(target_brand_name, BRAND_PROFILES["Nike"])
    
    prompt_template_string = """
    Your role is to act as a senior Brand Consistency Analyst. Analyze the visual frame provided, which is focused on a product from the brand '{target_brand_name}'.
    
    Your analysis must strictly use the JSON format provided below. Do not add any text, explanations, or headings before or after the JSON block.
    
    {json_template}
    
    You must change "frame_status" to "FLAGGED" and "is_flagged_bad_frame" to "YES" if ANY of these brand-specific conditions are met:
    - Logo Score is less than {logo_min_score}.
    - Visual Quality Score is less than {quality_min_score}.
    - Brand Tone Match is NO.
    """
    
    json_template = get_json_template_string()
    
    final_prompt = prompt_template_string.format(
        json_template=json_template,
        target_brand_name=target_brand_name,
        brand_visual_tone=profile["visual_tone"],
        logo_min_score=profile["flagging_criteria"]["logo_score_min"],
        quality_min_score=profile["flagging_criteria"]["quality_score_min"]
    )
    
    return final_prompt

# --- 3. PARALLEL PROCESSING FUNCTIONS ---

def process_single_frame(idx, frame_np_array, target_brand_name, client, prompt_template):
    """Analyzes a single frame and returns the compiled result dictionary."""
    
    try:
        # 1. Image preparation (encoding NumPy array to JPEG bytes)
        is_success, buffer = cv2.imencode(".jpg", frame_np_array)
        if not is_success:
            raise ValueError("Image encoding failed.")
        image_bytes = buffer.tobytes()
        image_part = Part.from_bytes(data=image_bytes, mime_type='image/jpeg')

        # 2. Call Gemini
        response = client.models.generate_content(
            model='gemini-2.5-flash',
            contents=[image_part, prompt_template]
        )
        
        # 3. Robust JSON Parsing (using the regex fix)
        response_text = response.text.strip()
        match = re.search(r'\{.*\}', response_text, re.DOTALL)
        if not match:
            raise json.JSONDecodeError("JSON block not found in response.", response_text, 0)
            
        json_text = match.group(0)
        frame_data = json.loads(json_text)
        
        # 4. Return data along with index
        return {"status": "SUCCESS", "index": idx, "data": frame_data}
        
    except Exception as e:
        # 5. Return error state
        return {"status": "ERROR", "index": idx, "error": str(e), "raw_response": response.text if 'response' in locals() else 'N/A'}


def analyze_and_compile_report_parallel(final_annotated_frames, target_brand_name, client, max_workers=30):
    """Processes all frames in parallel using ThreadPoolExecutor."""
    
    # Initialize report structure
    global_report = {
        "analysis_summary": {
            "total_frames_analyzed": len(final_annotated_frames),
            "total_flagged_frames": 0,
            "average_logo_score": 0.0,
            "average_quality_score": 0.0
        },
        "flagged_frames_details": [],
        "all_frames_data": []
    }
    
    total_logo_scores = []
    total_quality_scores = []
    prompt_template = get_single_frame_prompt_custom(target_brand_name)
    
    print(f"\n--- Starting Parallel Analysis for {len(final_annotated_frames)} Frames (Max Workers: {max_workers}) ---")
    
    # Execute in parallel
    futures = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        for idx, frame_np_array in enumerate(final_annotated_frames):
            future = executor.submit(
                process_single_frame, 
                idx, 
                frame_np_array, 
                target_brand_name, 
                client, 
                prompt_template
            )
            futures.append(future)

        # Retrieve results as they complete
        for future in as_completed(futures):
            result = future.result()
            idx = result["index"]
            
            if result["status"] == "SUCCESS":
                frame_data = result["data"]
                
                # Robust score extraction and conversion
                try:
                    logo_score = float(frame_data['metrics']['logo_presence_score']['score'].replace('[', '').replace(']', ''))
                    quality_score = float(frame_data['metrics']['visual_quality_score']['score'].replace('[', '').replace(']', ''))
                except Exception:
                    logo_score, quality_score = 0.0, 0.0

                total_logo_scores.append(logo_score)
                total_quality_scores.append(quality_score)
                
                # Flagging logic
                profile = BRAND_PROFILES.get(target_brand_name, BRAND_PROFILES["Nike"])
                logo_min = profile["flagging_criteria"]["logo_score_min"]
                quality_min = profile["flagging_criteria"]["quality_score_min"]
                tone_match = frame_data['metrics']['brand_tone_match']['match'].upper()

                if logo_score < logo_min or quality_score < quality_min or tone_match == 'NO':
                     frame_data['is_flagged_bad_frame'] = 'YES'
                     frame_data['frame_status'] = 'FLAGGED'
                
                if frame_data.get('is_flagged_bad_frame', 'NO').upper() == 'YES':
                    global_report["analysis_summary"]["total_flagged_frames"] += 1
                    global_report["flagged_frames_details"].append({
                        "frame_index": idx,
                        "reason": frame_data.get('flag_reason', 'Criteria met for flagging'),
                        "summary": frame_data['final_summary']
                    })
                
                frame_data['frame_index'] = idx
                global_report["all_frames_data"].append(frame_data)
                print(f"✅ Frame {idx + 1} processed successfully.")

            else: # Error handling
                print(f"❌ Error processing Frame {idx + 1}: {result['error']}")
                global_report["all_frames_data"].append({"frame_index": idx, "status": "API_ERROR", "error_message": result['error'], "raw_response": result.get('raw_response', 'N/A')})

    # Calculate Global Averages
    global_report["analysis_summary"]["average_logo_score"] = np.mean(total_logo_scores) if total_logo_scores else 0.0
    global_report["analysis_summary"]["average_quality_score"] = np.mean(total_quality_scores) if total_quality_scores else 0.0
    
    return global_report

# %%
# --- 4. EXECUTION EXAMPLE ---

TARGET_BRAND = "Nike" 
final_compiled_json_report = analyze_and_compile_report_parallel(
    final_annotated_frames=final_annotated_frames,
    target_brand_name=TARGET_BRAND,
    client=gemini_client,
    max_workers=30 
)
# Out:
# --- Starting Parallel Analysis for 307 Frames (Max Workers: 30) ---
# ✅ Frame 1 processed successfully.
# ✅ Frame 29 processed successfully.
# ✅ Frame 12 processed successfully.
# ✅ Frame 17 processed successfully.
# ✅ Frame 4 processed successfully.
# ✅ Frame 21 processed successfully.
# ✅ Frame 30 processed successfully.
# ✅ Frame 24 processed successfully.
# ✅ Frame 14 processed successfully.
# ✅ Frame 25 processed successfully.
# ✅ Frame 27 processed successfully.
# ✅ Frame 6 processed successfully.
# ✅ Frame 11 processed successfully.
# ✅ Frame 3 processed successfully.
# ✅ Frame 28 processed successfully.
# ✅ Frame 15 processed successfully.
# ✅ Frame 26 processed successfully.
# ✅ Frame 9 processed successfully.
# ✅ Frame 22 processed successfully.
# ✅ Frame 23 processed successfully.
# ✅ Frame 5 processed successfully.
# ✅ Frame 10 processed successfully.
# ✅ Frame 19 processed successfully.
# ✅ Frame 13 processed successfully.
# ✅ Frame 16 processed successfully.
# ✅ Frame 2 processed successfully.
# ✅ Frame 7 processed successfully.
# ✅ Frame 18 processed successfully.
# ✅ Frame 20 processed successfully.
# ✅ Frame 8 processed successfully.
# ✅ Frame 38 processed successfully.
# ✅ Frame 47 processed successfully.
# ✅ Frame 32 processed successfully.
# ✅ Frame 39 processed successfully.
# ✅ Frame 36 processed successfully.
# ✅ Frame 34 processed successfully.
# ✅ Frame 43 processed successfully.
# ✅ Frame 53 processed successfully.
# ✅ Frame 37 processed successfully.
# ✅ Frame 44 processed successfully.
# ✅ Frame 40 processed successfully.
# ✅ Frame 45 processed successfully.
# ✅ Frame 46 processed successfully.
# ✅ Frame 41 processed successfully.
# ✅ Frame 56 processed successfully.
# ✅ Frame 48 processed successfully.
# ✅ Frame 50 processed successfully.
# ✅ Frame 35 processed successfully.
# ✅ Frame 51 processed successfully.
# ✅ Frame 52 processed successfully.
# ✅ Frame 42 processed successfully.
# ✅ Frame 31 processed successfully.
# ✅ Frame 33 processed successfully.
# ✅ Frame 57 processed successfully.
# ✅ Frame 49 processed successfully.
# ✅ Frame 54 processed successfully.
# ✅ Frame 58 processed successfully.
# ✅ Frame 61 processed successfully.
# ✅ Frame 59 processed successfully.
# ✅ Frame 55 processed successfully.
# ✅ Frame 60 processed successfully.
# ✅ Frame 65 processed successfully.
# ✅ Frame 62 processed successfully.
# ✅ Frame 67 processed successfully.
# ✅ Frame 63 processed successfully.
# ✅ Frame 64 processed successfully.
# ✅ Frame 70 processed successfully.
# ✅ Frame 73 processed successfully.
# ✅ Frame 68 processed successfully.
# ✅ Frame 76 processed successfully.
# ✅ Frame 66 processed successfully.
# ✅ Frame 69 processed successfully.
# ✅ Frame 82 processed successfully.
# ✅ Frame 84 processed successfully.
# ✅ Frame 71 processed successfully.
# ✅ Frame 72 processed successfully.
# ✅ Frame 75 processed successfully.
# ✅ Frame 78 processed successfully.
# ✅ Frame 74 processed successfully.
# ✅ Frame 83 processed successfully.
# ✅ Frame 79 processed successfully.
# ✅ Frame 86 processed successfully.
# ✅ Frame 88 processed successfully.
# ✅ Frame 87 processed successfully.
# ✅ Frame 81 processed successfully.
# ✅ Frame 80 processed successfully.
# ✅ Frame 90 processed successfully.
# ✅ Frame 85 processed successfully.
# ✅ Frame 89 processed successfully.
# ✅ Frame 77 processed successfully.
# ✅ Frame 97 processed successfully.
# ✅ Frame 105 processed successfully.
# ✅ Frame 98 processed successfully.
# ✅ Frame 91 processed successfully.
# ✅ Frame 108 processed successfully.
# ✅ Frame 101 processed successfully.
# ✅ Frame 99 processed successfully.
# ✅ Frame 103 processed successfully.
# ✅ Frame 102 processed successfully.
# ✅ Frame 93 processed successfully.
# ✅ Frame 107 processed successfully.
# ✅ Frame 111 processed successfully.
# ✅ Frame 113 processed successfully.
# ✅ Frame 95 processed successfully.
# ✅ Frame 106 processed successfully.
# ✅ Frame 94 processed successfully.
# ✅ Frame 110 processed successfully.
# ✅ Frame 96 processed successfully.
# ✅ Frame 114 processed successfully.
# ✅ Frame 92 processed successfully.
# ✅ Frame 112 processed successfully.
# ✅ Frame 109 processed successfully.
# ✅ Frame 116 processed successfully.
# ✅ Frame 118 processed successfully.
# ✅ Frame 104 processed successfully.
# ✅ Frame 119 processed successfully.
# ✅ Frame 121 processed successfully.
# ✅ Frame 117 processed successfully.
# ✅ Frame 122 processed successfully.
# ✅ Frame 120 processed successfully.
# ✅ Frame 128 processed successfully.
# ✅ Frame 130 processed successfully.
# ✅ Frame 115 processed successfully.
# ✅ Frame 123 processed successfully.
# ✅ Frame 125 processed successfully.
# ✅ Frame 127 processed successfully.
# ✅ Frame 131 processed successfully.
# ✅ Frame 133 processed successfully.
# ✅ Frame 124 processed successfully.
# ✅ Frame 126 processed successfully.
# ✅ Frame 129 processed successfully.
# ✅ Frame 136 processed successfully.
# ✅ Frame 143 processed successfully.
# ✅ Frame 132 processed successfully.
# ✅ Frame 146 processed successfully.
# ✅ Frame 138 processed successfully.
# ✅ Frame 142 processed successfully.
# ✅ Frame 135 processed successfully.
# ✅ Frame 148 processed successfully.
# ✅ Frame 151 processed successfully.
# ✅ Frame 157 processed successfully.
# ✅ Frame 100 processed successfully.
# ✅ Frame 145 processed successfully.
# ✅ Frame 154 processed successfully.
# ✅ Frame 153 processed successfully.
# ✅ Frame 139 processed successfully.
# ✅ Frame 144 processed successfully.
# ✅ Frame 152 processed successfully.
# ✅ Frame 134 processed successfully.
# ✅ Frame 155 processed successfully.
# ✅ Frame 163 processed successfully.
# ✅ Frame 156 processed successfully.
# ✅ Frame 150 processed successfully.
# ✅ Frame 140 processed successfully.
# ✅ Frame 160 processed successfully.
# ✅ Frame 161 processed successfully.
# ✅ Frame 159 processed successfully.
# ✅ Frame 162 processed successfully.
# ✅ Frame 167 processed successfully.
# ✅ Frame 165 processed successfully.
# ✅ Frame 164 processed successfully.
# ✅ Frame 168 processed successfully.
# ✅ Frame 178 processed successfully.
# ✅ Frame 149 processed successfully.
# ✅ Frame 158 processed successfully.
# ✅ Frame 173 processed successfully.
# ✅ Frame 180 processed successfully.
# ✅ Frame 176 processed successfully.
# ✅ Frame 137 processed successfully.
# ✅ Frame 141 processed successfully.
# ✅ Frame 175 processed successfully.
# ✅ Frame 169 processed successfully.
# ✅ Frame 182 processed successfully.
# ✅ Frame 181 processed successfully.
# ✅ Frame 174 processed successfully.
# ✅ Frame 166 processed successfully.
# ✅ Frame 179 processed successfully.
# ✅ Frame 177 processed successfully.
# ✅ Frame 184 processed successfully.
# ✅ Frame 170 processed successfully.
# ✅ Frame 172 processed successfully.
# ✅ Frame 183 processed successfully.
# ✅ Frame 188 processed successfully.
# ✅ Frame 187 processed successfully.
# ✅ Frame 171 processed successfully.
# ✅ Frame 186 processed successfully.
# ✅ Frame 189 processed successfully.
# ✅ Frame 192 processed successfully.
# ✅ Frame 191 processed successfully.
# ✅ Frame 194 processed successfully.
# ✅ Frame 195 processed successfully.
# ✅ Frame 193 processed successfully.
# ✅ Frame 147 processed successfully.
# ✅ Frame 199 processed successfully.
# ✅ Frame 190 processed successfully.
# ✅ Frame 206 processed successfully.
# ✅ Frame 197 processed successfully.
# ✅ Frame 201 processed successfully.
# ✅ Frame 202 processed successfully.
# ✅ Frame 203 processed successfully.
# ✅ Frame 205 processed successfully.
# ✅ Frame 185 processed successfully.
# ✅ Frame 207 processed successfully.
# ✅ Frame 209 processed successfully.
# ✅ Frame 200 processed successfully.
# ✅ Frame 212 processed successfully.
# ✅ Frame 213 processed successfully.
# ✅ Frame 214 processed successfully.
# ✅ Frame 198 processed successfully.
# ✅ Frame 210 processed successfully.
# ✅ Frame 211 processed successfully.
# ✅ Frame 208 processed successfully.
# ✅ Frame 216 processed successfully.
# ✅ Frame 196 processed successfully.
# ✅ Frame 215 processed successfully.
# ✅ Frame 217 processed successfully.
# ✅ Frame 218 processed successfully.
# ✅ Frame 219 processed successfully.
# ✅ Frame 220 processed successfully.
# ✅ Frame 222 processed successfully.
# ✅ Frame 234 processed successfully.
# ✅ Frame 230 processed successfully.
# ✅ Frame 229 processed successfully.
# ✅ Frame 227 processed successfully.
# ✅ Frame 204 processed successfully.
# ✅ Frame 242 processed successfully.
# ✅ Frame 233 processed successfully.
# ✅ Frame 237 processed successfully.
# ✅ Frame 239 processed successfully.
# ✅ Frame 243 processed successfully.
# ✅ Frame 232 processed successfully.
# ✅ Frame 238 processed successfully.
# ✅ Frame 240 processed successfully.
# ✅ Frame 221 processed successfully.
# ✅ Frame 248 processed successfully.
# ✅ Frame 241 processed successfully.
# ✅ Frame 223 processed successfully.
# ✅ Frame 246 processed successfully.
# ✅ Frame 235 processed successfully.
# ✅ Frame 250 processed successfully.
# ✅ Frame 224 processed successfully.
# ✅ Frame 251 processed successfully.
# ✅ Frame 249 processed successfully.
# ✅ Frame 226 processed successfully.
# ✅ Frame 254 processed successfully.
# ✅ Frame 231 processed successfully.
# ✅ Frame 245 processed successfully.
# ✅ Frame 244 processed successfully.
# ✅ Frame 258 processed successfully.
# ✅ Frame 253 processed successfully.
# ✅ Frame 252 processed successfully.
# ✅ Frame 257 processed successfully.
# ✅ Frame 255 processed successfully.
# ✅ Frame 225 processed successfully.
# ✅ Frame 261 processed successfully.
# ✅ Frame 263 processed successfully.
# ✅ Frame 256 processed successfully.
# ✅ Frame 260 processed successfully.
# ✅ Frame 272 processed successfully.
# ✅ Frame 271 processed successfully.
# ✅ Frame 274 processed successfully.
# ✅ Frame 268 processed successfully.
# ✅ Frame 269 processed successfully.
# ✅ Frame 247 processed successfully.
# ✅ Frame 265 processed successfully.
# ✅ Frame 259 processed successfully.
# ✅ Frame 277 processed successfully.
# ✅ Frame 264 processed successfully.
# ✅ Frame 273 processed successfully.
# ✅ Frame 276 processed successfully.
# ✅ Frame 267 processed successfully.
# ✅ Frame 262 processed successfully.
# ✅ Frame 281 processed successfully.
# ✅ Frame 280 processed successfully.
# ✅ Frame 275 processed successfully.
# ✅ Frame 270 processed successfully.
# ✅ Frame 266 processed successfully.
# ✅ Frame 283 processed successfully.
# ✅ Frame 284 processed successfully.
# ✅ Frame 282 processed successfully.
# ✅ Frame 287 processed successfully.
# ✅ Frame 289 processed successfully.
# ✅ Frame 286 processed successfully.
# ✅ Frame 290 processed successfully.
# ✅ Frame 297 processed successfully.
# ✅ Frame 278 processed successfully.
# ✅ Frame 291 processed successfully.
# ✅ Frame 285 processed successfully.
# ✅ Frame 228 processed successfully.
# ✅ Frame 279 processed successfully.
# ✅ Frame 294 processed successfully.
# ✅ Frame 300 processed successfully.
# ✅ Frame 292 processed successfully.
# ✅ Frame 298 processed successfully.
# ✅ Frame 302 processed successfully.
# ✅ Frame 301 processed successfully.
# ✅ Frame 296 processed successfully.
# ✅ Frame 293 processed successfully.
# ✅ Frame 295 processed successfully.
# ✅ Frame 288 processed successfully.
# ✅ Frame 299 processed successfully.
# ✅ Frame 303 processed successfully.
# ✅ Frame 305 processed successfully.
# ✅ Frame 306 processed successfully.
# ✅ Frame 304 processed successfully.
# ✅ Frame 307 processed successfully.
# ✅ Frame 236 processed successfully.
# {
#   "analysis_summary": {
#     "total_frames_analyzed": 307,
#     "total_flagged_frames": 194,
#     "average_logo_score": 0.43534201954397395,
#     "average_quality_score": 1.9022801302931596
#   },
#   "flagged_frames_details": [
#     {
#       "frame_index": 28,
#       "reason": "Logo is absent, visual quality is very poor, and brand tone does not match.",
#       "summary": "This frame is non-conforming as the Nike logo is absent, visual quality is extremely poor, and the overall ambiance and product context do not align with the brand's identity."
#     },
#     {
#       "frame_index": 11,
#       "reason": "Logo Score is less than 0.5 and Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo and extremely poor visual quality of the product, despite relevant product placement and brand tone match."
#     },
#     {
#       "frame_index": 20,
#       "reason": "Logo Score is less than 0.5 and Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of the brand logo and very poor visual quality of the product caused by excessive motion blur, despite depicting a relevant athletic context."
#     },
#     {
#       "frame_index": 29,
#       "reason": "Nike logo is absent, and the visual quality of the runner is very poor due to motion blur.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo and very poor visual quality of the runner because of motion blur, despite the relevant athletic context."
#     },
#     {
#       "frame_index": 23,
#       "reason": "Logo not visible, visual quality is very poor due to motion blur, and the resulting image quality does not match the brand's visual tone.",
#       "summary": "The frame is flagged as bad due to the complete absence of a visible Nike logo, extremely poor visual quality from motion blur, and a resulting mismatch with the brand's desired tone, despite the relevant product context."
#     },
#     {
#       "frame_index": 24,
#       "reason": "Logo Score is less than 0.5 and Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of a visible Nike logo and extremely poor visual quality, although the athletic context is relevant to the brand."
#     },
#     {
#       "frame_index": 5,
#       "reason": "Brand Tone Mismatch",
#       "summary": "The frame is flagged as it fails to match Nike's energetic brand tone, despite the logo being clearly visible and the product context being relevant."
#     },
#     {
#       "frame_index": 10,
#       "reason": "None",
#       "summary": "The frame is compliant, featuring a clearly visible Nike logo on relevant athletic wear within an appropriate active urban context, despite moderate visual clarity."
#     },
#     {
#       "frame_index": 27,
#       "reason": "Nike logo is absent and the visual quality of the product is very poor due to extreme motion blur.",
#       "summary": "The frame is flagged as bad due to the complete absence of the Nike logo and extremely poor visual quality of the product, despite the relevant athletic context."
#     },
#     {
#       "frame_index": 14,
#       "reason": "Logo Score is less than 0.5: The Nike logo is not clearly visible or recognizable on the sport shoes.",
#       "summary": "The frame depicts a context relevant to Nike's brand tone and product placement, but it is flagged because the Nike logo is not clearly visible on the sport shoes."
#     },
#     {
#       "frame_index": 25,
#       "reason": "Logo Score is less than 0.5 and Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the unrecognizable brand logo and very poor visual quality of the product focus area, despite the relevant athletic context."
#     },
#     {
#       "frame_index": 21,
#       "reason": "Logo Score is less than 0.5, Visual Quality Score is less than 2, and Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to the complete absence of a visible logo, extremely poor visual quality from severe motion blur, and a resultant mismatch with Nike's desired brand tone."
#     },
#     {
#       "frame_index": 22,
#       "reason": "Logo score is below 0.5, visual quality score is below 2, and brand tone match is NO.",
#       "summary": "This frame is flagged because the Nike logo is absent, the visual quality is very poor with significant blur, and the brand's dynamic tone cannot be effectively conveyed."
#     },
#     {
#       "frame_index": 4,
#       "reason": "Brand tone does not match.",
#       "summary": "The frame is flagged as the overall mood and composition do not align with Nike's typical brand tone, despite good logo visibility and relevant product context."
#     },
#     {
#       "frame_index": 9,
#       "reason": "Brand tone mismatch due to low visual quality and the presence of distracting AI-generated elements that do not reflect Nike's brand standards.",
#       "summary": "The frame is flagged due to a significant mismatch with Nike's brand tone, primarily caused by poor visual quality and the presence of distracting AI-generated elements, despite a clearly visible logo and relevant product placement."
#     },
#     {
#       "frame_index": 18,
#       "reason": "Logo Score is 0.0 (less than 0.5) and Brand Tone Match is NO due to the presence of a non-Nike brand logo.",
#       "summary": "The frame is flagged as non-conformant because the Nike logo is absent, and a different brand's logo is prominently featured, leading to a mismatch in brand tone and product relevance."
#     },
#     {
#       "frame_index": 12,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged because no Nike logo is clearly visible on the sport shoes, despite the product placement and visual tone being highly relevant to the brand."
#     },
#     {
#       "frame_index": 15,
#       "reason": "Nike logo is not clearly visible or recognizable on the product.",
#       "summary": "The frame is flagged because the Nike logo is not clearly visible on the product, despite good visual quality, relevant product placement, and a matching brand tone."
#     },
#     {
#       "frame_index": 6,
#       "reason": "Brand Tone Match is NO, and Product Placement Relevance is NO.",
#       "summary": "The frame is flagged due to a mismatch with Nike's brand tone and product placement relevance, as the static building context and limiting text 'only sport shoes' do not align with the brand's dynamic and comprehensive athletic identity."
#     },
#     {
#       "frame_index": 19,
#       "reason": "Logo score is below 0.5, visual quality score is below 2, and brand tone match is NO.",
#       "summary": "The frame is flagged due to an unrecognizable logo, extremely poor visual quality for product presentation, and a significant mismatch with Nike's established brand tone."
#     },
#     {
#       "frame_index": 7,
#       "reason": "None",
#       "summary": "The frame demonstrates strong brand coherence with a perfectly visible Nike logo and highly relevant product messaging, effectively communicating the brand's identity."
#     },
#     {
#       "frame_index": 37,
#       "reason": "Logo Score is less than 0.5 AND Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo and the very poor visual quality of the product, though the context and brand tone are appropriate."
#     },
#     {
#       "frame_index": 46,
#       "reason": "Logo Score is less than 0.5, Visual Quality Score is less than 2, and Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to the complete absence of a discernible Nike logo, extremely poor visual quality, and a lack of alignment with Nike's brand tone, rendering it non-compliant."
#     },
#     {
#       "frame_index": 31,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame depicts a relevant active context for Nike but is flagged due to the complete absence of the brand logo and poor visual quality of the product focus area."
#     },
#     {
#       "frame_index": 38,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged due to the complete absence of a visible Nike logo, despite the athletic context being highly relevant and aligning with the brand's tone."
#     },
#     {
#       "frame_index": 33,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame depicts a relevant active outdoor context for athletic footwear but is flagged due to the complete absence of any visible Nike logo, preventing brand identification."
#     },
#     {
#       "frame_index": 42,
#       "reason": "Logo Score is less than 0.5 and Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of a visible Nike logo and the extremely poor visual quality of the product area, despite the relevant active context aligning with the brand tone."
#     },
#     {
#       "frame_index": 52,
#       "reason": "Logo Score is less than 0.5, Visual Quality Score is less than 2, and Brand Tone Match is NO.",
#       "summary": "The frame is flagged as bad due to the complete absence of a visible Nike logo, extremely poor visual quality, and a significant mismatch with the brand's energetic tone."
#     },
#     {
#       "frame_index": 36,
#       "reason": "Visual quality score of the product focus area is less than 2 due to severe motion blur.",
#       "summary": "The frame is flagged due to very poor visual quality of the product, which is severely blurred despite the strong alignment with Nike's active brand tone and relevant product placement."
#     },
#     {
#       "frame_index": 43,
#       "reason": "Nike logo is absent, visual quality is very poor (score 1), and the frame's mood does not match Nike's brand tone.",
#       "summary": "This frame is flagged due to the complete absence of Nike branding, extremely poor visual quality, and a complete mismatch with Nike's brand tone and product relevance."
#     },
#     {
#       "frame_index": 39,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame effectively conveys an active context relevant to Nike's brand identity, but it is flagged due to the complete absence of a visible Nike logo and the poor visual quality of the product."
#     },
#     {
#       "frame_index": 44,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo and extremely poor visual quality, though the dynamic motion blur aligns with the brand's tone."
#     },
#     {
#       "frame_index": 45,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "summary": "The frame is flagged as bad due to the complete absence of a visible Nike logo, very poor visual quality of the product, and a mismatch with Nike's dynamic brand tone, despite the product being in a relevant athletic context."
#     },
#     {
#       "frame_index": 40,
#       "reason": "Nike logo not visible (score < 0.5) and very poor visual quality of the product area (score < 2).",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo and very poor visual quality of the product area, despite the relevant athletic context."
#     },
#     {
#       "frame_index": 55,
#       "reason": "Nike logo is not clearly visible, and the visual quality of the product focus area is very poor.",
#       "summary": "The frame is flagged due to the absence of a discernible Nike logo and very poor visual quality of the product focus area, despite the relevant product placement and brand tone match."
#     },
#     {
#       "frame_index": 47,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo, despite the textual content and overall aesthetic being highly relevant to the brand's identity."
#     },
#     {
#       "frame_index": 49,
#       "reason": "Nike logo is absent, visual quality is poor, and the brand tone does not match Nike's identity.",
#       "summary": "The frame is flagged as bad due to the complete absence of any Nike logo, poor visual quality, and a scene that fails to align with Nike's brand tone and product context relevance."
#     },
#     {
#       "frame_index": 34,
#       "reason": "None",
#       "summary": "The frame is coherent with the Nike brand, effectively showing the product in an active context, despite the visual quality being compromised by motion blur."
#     },
#     {
#       "frame_index": 50,
#       "reason": "Logo Score is less than 0.5, Visual Quality Score is less than 2, Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to the complete absence of a discernible Nike logo, extremely poor visual quality of the product focus, and a mismatch with the brand's aspirational tone."
#     },
#     {
#       "frame_index": 51,
#       "reason": "Logo Score is 0.0 (less than 0.5); Visual Quality Score is 1 (less than 2); Brand Tone Match is NO.",
#       "summary": "This frame is flagged as bad due to the complete absence of any discernible Nike logo, extremely poor visual quality, and a significant mismatch with Nike's brand tone and product placement relevance."
#     },
#     {
#       "frame_index": 41,
#       "reason": "Logo Score is 0.1, which is less than the threshold of 0.5.",
#       "summary": "The frame is flagged because the Nike logo is not clearly visible on the product, despite the strong relevance of the athletic context and brand tone match."
#     },
#     {
#       "frame_index": 30,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "summary": "The frame is flagged as non-compliant due to the complete absence of any Nike logo or product, extremely poor visual quality, and a significant mismatch with Nike's brand tone."
#     },
#     {
#       "frame_index": 32,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged due to the absence of a clearly visible Nike logo, despite the strong relevance of the product placement and alignment with the brand's dynamic tone."
#     },
#     {
#       "frame_index": 48,
#       "reason": "Logo Score is less than 0.5 and Brand Tone Match is NO.",
#       "summary": "The frame is non-compliant as no Nike product or logo is visible, and the overall visual tone does not match the brand's athletic and inspiring aesthetic."
#     },
#     {
#       "frame_index": 53,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of any discernible Nike logo and very poor visual quality, despite the context being relevant to the brand's tone and product placement."
#     },
#     {
#       "frame_index": 57,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged because the Nike logo is not clearly visible or recognizable, despite relevant product placement and brand tone match."
#     },
#     {
#       "frame_index": 60,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged due to the complete absence of any visible Nike logo, despite the product being relevantly placed in an athletic context that aligns with the brand's tone."
#     },
#     {
#       "frame_index": 58,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged because the Nike logo is completely absent, although the visual tone and product context are relevant to the brand."
#     },
#     {
#       "frame_index": 59,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged due to the absence of a clearly visible or recognizable Nike logo, despite depicting a context highly relevant to the brand's identity and having an appropriate brand tone."
#     },
#     {
#       "frame_index": 64,
#       "reason": "Logo is absent, visual quality is very poor, and the brand tone does not match Nike's identity.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo, very poor visual quality, and a significant mismatch with the brand's visual tone, with no product visible."
#     },
#     {
#       "frame_index": 61,
#       "reason": "Logo not visible and very poor visual quality of the product focus area.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo and very poor visual quality, despite the context being relevant to the brand."
#     },
#     {
#       "frame_index": 66,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "summary": "The frame is flagged as bad due to the complete absence of the Nike logo, extremely poor visual quality, and a total mismatch with the brand's visual tone and identity."
#     },
#     {
#       "frame_index": 62,
#       "reason": "Logo is absent and visual quality is very poor due to severe motion blur on the main subject.",
#       "summary": "The frame is flagged due to the complete absence of a visible Nike logo and very poor visual quality of the product focus area, despite good brand tone and product placement relevance."
#     },
#     {
#       "frame_index": 63,
#       "reason": "Logo Score is less than 0.5 and Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of a visible Nike logo and very poor visual quality of the subject, despite the context being relevant to the brand's active tone."
#     },
#     {
#       "frame_index": 69,
#       "reason": "Logo score is less than 0.5, visual quality score is less than 2, and brand tone match is NO.",
#       "summary": "This frame is flagged due to the complete absence of a visible Nike logo, extremely poor visual quality caused by motion blur, and the inability of the image to effectively convey the brand's intended athletic and energetic tone."
#     },
#     {
#       "frame_index": 72,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame captures an athletic aesthetic in an urban setting consistent with Nike's brand tone, but it is flagged as the Nike logo is entirely absent, making brand product identification impossible."
#     },
#     {
#       "frame_index": 67,
#       "reason": "Logo is absent, visual quality is very poor due to extreme blur, and the severe blur compromises the effective communication of the brand tone.",
#       "summary": "The frame is flagged due to very poor visual quality, the absence of a visible logo, and the inability to effectively convey the brand's tone despite a relevant product context."
#     },
#     {
#       "frame_index": 75,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "This frame is flagged for brand inconsistency due to the complete absence of the Nike logo, despite the product context and brand tone being highly relevant."
#     },
#     {
#       "frame_index": 65,
#       "reason": "Logo Score is less than 0.5 and Brand Tone Match is NO.",
#       "summary": "This frame is flagged as bad due to the complete absence of any Nike branding or product, and the overall scene fails to align with Nike's brand tone."
#     },
#     {
#       "frame_index": 68,
#       "reason": "Nike logo is absent from the frame.",
#       "summary": "The frame is flagged because the Nike logo is completely absent, although the product placement is relevant to the brand's identity, the visual quality is poor."
#     },
#     {
#       "frame_index": 81,
#       "reason": "Nike logo is absent.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo, despite otherwise good brand tone match and product placement relevance."
#     },
#     {
#       "frame_index": 71,
#       "reason": "The Nike logo is entirely absent, and a different brand's logo is prominently displayed on the product.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo, despite the visual quality, brand tone, and product placement context being otherwise suitable for an athletic brand."
#     },
#     {
#       "frame_index": 74,
#       "reason": "Logo Score is less than 0.5, Visual Quality Score is less than 2, and Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo, very poor visual quality marked by significant blurriness, and a brand tone that does not cohere with Nike's typical high-quality aesthetic."
#     },
#     {
#       "frame_index": 73,
#       "reason": "Nike logo is absent.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo, despite an otherwise relevant brand tone and context."
#     },
#     {
#       "frame_index": 82,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged due to the complete absence of a recognizable Nike logo and poor visual quality, despite matching the brand's tone and product placement relevance."
#     },
#     {
#       "frame_index": 78,
#       "reason": "Nike logo is absent from the frame.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo, despite the visual tone and product placement being highly relevant to the brand."
#     },
#     {
#       "frame_index": 85,
#       "reason": "Logo Score is less than 0.5 and Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of a clearly recognizable Nike logo and very poor visual quality, despite the athletic product placement and relevant brand tone."
#     },
#     {
#       "frame_index": 87,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo, extremely poor visual quality, and a generic, dark context that does not align with the brand's tone or identity."
#     },
#     {
#       "frame_index": 86,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to the complete absence of a visible logo, extremely poor visual quality, and a significant mismatch with the brand's visual tone."
#     },
#     {
#       "frame_index": 80,
#       "reason": "Nike logo is completely absent, and other brand logos ('QUARTERMILE' and a distinct jacket logo) are visible instead.",
#       "summary": "The frame is flagged because the Nike logo is entirely absent, and other brand identifiers are present, failing to represent the target brand's product, despite matching visual tone and product context."
#     },
#     {
#       "frame_index": 79,
#       "reason": "Nike logo is absent, and a competing brand ('Quartermile') is visibly featured, leading to a logo score below 0.5 and a mismatch in brand tone.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo and the clear presence of branding for another company, 'Quartermile', which directly contradicts the target brand."
#     },
#     {
#       "frame_index": 89,
#       "reason": "Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to a significant mismatch with Nike's brand tone, despite the logo being clearly visible and product placement being relevant."
#     },
#     {
#       "frame_index": 84,
#       "reason": "Logo Score is less than 0.5 and Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of a visible Nike logo and very poor visual quality, despite the product being placed in a relevant athletic urban context that generally aligns with the brand's tone."
#     },
#     {
#       "frame_index": 88,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to an absent logo, very poor visual quality, and a complete mismatch with Nike's brand tone and product placement relevance."
#     },
#     {
#       "frame_index": 76,
#       "reason": "Nike logo is absent (score 0.0). The frame also explicitly features other brand names and logos, promoting non-Nike products.",
#       "summary": "The frame is flagged due to the complete absence of Nike branding and the presence of other brand logos, making it inconsistent with brand guidelines despite the visual tone being aligned with Nike's aesthetic."
#     },
#     {
#       "frame_index": 96,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo, despite the product placement being relevant and the overall tone aligning with the brand."
#     },
#     {
#       "frame_index": 90,
#       "reason": "Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the poor visual quality and lack of sharpness of the product (shoes), despite the logo being clear and context relevant to the brand."
#     },
#     {
#       "frame_index": 110,
#       "reason": "None",
#       "summary": "The frame is highly consistent with the Nike Running brand, featuring a clear logo, good visual quality, and relevant product placement in an appropriate active urban setting."
#     },
#     {
#       "frame_index": 94,
#       "reason": "Logo Score is less than 0.5, as the Nike logo is not clearly visible or recognizable.",
#       "summary": "The frame is flagged due to the Nike logo being virtually absent and unrecognizable, despite the overall tone and product placement being relevant to the brand."
#     },
#     {
#       "frame_index": 93,
#       "reason": "Visual quality score is less than 2 and brand tone match is NO. Additionally, product placement is inconsistent with the brand's core product.",
#       "summary": "The frame is flagged due to very poor visual quality, a mismatch with the brand's tone, and highly inconsistent product placement where the Nike logo is present but the actual sport shoe product is absent or heavily obscured, contradicting the explicit text."
#     },
#     {
#       "frame_index": 95,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "summary": "The frame is flagged as bad due to the complete absence of the Nike logo, the poor visual quality and blurriness of the product, and a mismatch with Nike's dynamic brand tone."
#     },
#     {
#       "frame_index": 91,
#       "reason": "None",
#       "summary": "The frame is generally compliant with good visual quality and brand tone, however, the product placement is inconsistent due to bare feet being shown despite the 'only sport shoes' label."
#     },
#     {
#       "frame_index": 111,
#       "reason": "None",
#       "summary": "The frame is highly conformant, showcasing clear Nike branding with relevant product placement and a visual tone consistent with the brand's athletic and modern identity."
#     },
#     {
#       "frame_index": 103,
#       "reason": "None",
#       "summary": "The frame conforms with clear logo presence, good brand tone, and relevant product placement, though the visual quality of the product focus area is notably blurry."
#     },
#     {
#       "frame_index": 121,
#       "reason": "None",
#       "summary": "The frame is consistent with the Nike Running brand, showcasing a clearly visible logo and a relevant, well-executed visual context that aligns with the brand's dynamic and authentic tone."
#     },
#     {
#       "frame_index": 127,
#       "reason": "None",
#       "summary": "The frame fully conforms to brand guidelines, featuring a clear Nike logo and highly relevant context for its running segment with good visual quality and brand tone match."
#     },
#     {
#       "frame_index": 123,
#       "reason": "None",
#       "summary": "The frame is fully compliant with Nike's brand guidelines, showcasing clear branding, good visual quality, and an energetic, relevant context."
#     },
#     {
#       "frame_index": 128,
#       "reason": "None",
#       "summary": "The frame is highly conformant with Nike's brand guidelines, featuring clear branding, good visual quality, and a highly relevant context that aligns with the brand's tone."
#     },
#     {
#       "frame_index": 135,
#       "reason": "Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to a significant mismatch with Nike's established brand tone, despite clear logo presence and relevant product context."
#     },
#     {
#       "frame_index": 145,
#       "reason": "None",
#       "summary": "The frame shows good brand coherence with a clearly visible Nike logo and relevant product placement, despite some blurriness affecting overall visual quality."
#     },
#     {
#       "frame_index": 137,
#       "reason": "Logo Score is less than 0.5 and Brand Tone Match is NO.",
#       "summary": "The frame is flagged as non-compliant due to the complete absence of any visible Nike logo or product within the scene and a significant mismatch with Nike's characteristic dynamic brand tone."
#     },
#     {
#       "frame_index": 134,
#       "reason": "Visual Quality Score is 1 (less than 2) and Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to very poor visual quality caused by heavy pixelation and a digital glitch effect, and a significant mismatch with Nike's typical brand tone, despite clear logo presence and relevant product placement."
#     },
#     {
#       "frame_index": 99,
#       "reason": "None",
#       "summary": "The frame conforms to brand consistency, effectively showcasing a Nike sport shoe in a relevant urban context with a clear brand logo and appropriate visual tone, despite the product's stylized rendering."
#     },
#     {
#       "frame_index": 153,
#       "reason": "Brand Tone Mismatch",
#       "summary": "The frame is flagged as bad due to a significant mismatch with Nike's brand tone, despite the logo being clearly visible and the product being relevant."
#     },
#     {
#       "frame_index": 152,
#       "reason": "None",
#       "summary": "The frame is coherent with the Nike brand, effectively featuring the logo on a product in an active context, despite moderate blurriness in visual quality."
#     },
#     {
#       "frame_index": 138,
#       "reason": "Brand tone mismatch and absence of actual product placement in the scene.",
#       "summary": "The frame is flagged due to a significant mismatch with Nike's brand tone, characterized by low visual quality and a lack of dynamic energy, coupled with the absence of a physically placed Nike product in the scene."
#     },
#     {
#       "frame_index": 143,
#       "reason": "Brand Tone Match is NO.",
#       "summary": "The frame is flagged because its visual tone and low quality do not align with the Nike brand's identity, despite clear logo presence and relevant product placement."
#     },
#     {
#       "frame_index": 154,
#       "reason": "Brand Tone Match is NO.",
#       "summary": "The frame is flagged because the overall mood and visual quality do not match Nike's required brand tone, despite the logo being clearly visible and product placement being relevant."
#     },
#     {
#       "frame_index": 155,
#       "reason": "Brand Tone Match is NO.",
#       "summary": "The frame correctly identifies the Nike logo on a relevant product but is flagged due to the blurry visual quality and a brand tone that does not align with Nike's energetic aesthetic."
#     },
#     {
#       "frame_index": 149,
#       "reason": "Logo Score is less than 0.5. The Nike logo is not clearly visible or recognizable on the product.",
#       "summary": "This frame is flagged because the Nike logo on the product is not clearly visible, despite the product being in a relevant context and portraying an appropriate brand tone."
#     },
#     {
#       "frame_index": 159,
#       "reason": "Brand Tone Mismatch",
#       "summary": "The frame is flagged due to a significant mismatch in brand tone, despite the Nike logo being clearly visible and the product context being relevant."
#     },
#     {
#       "frame_index": 160,
#       "reason": "Brand Tone Mismatch",
#       "summary": "The frame displays a clear Nike logo with relevant product text, but the severe lack of visual context and poor lighting prevent it from matching Nike's characteristic energetic brand tone, leading to a flagged frame."
#     },
#     {
#       "frame_index": 158,
#       "reason": "Brand tone mismatch.",
#       "summary": "The frame is flagged due to a significant mismatch with Nike's energetic brand tone, as the image is overly dark and lacks dynamism, despite the clear presence of the Nike logo on a relevant product."
#     },
#     {
#       "frame_index": 166,
#       "reason": "None",
#       "summary": "The frame is highly conformant with the brand's visual identity, featuring a clear logo and a message directly relevant to Nike's core product category."
#     },
#     {
#       "frame_index": 167,
#       "reason": "None",
#       "summary": "The frame is highly coherent with the Nike brand, displaying a clear logo and a message directly relevant to its core product, all with excellent visual quality."
#     },
#     {
#       "frame_index": 177,
#       "reason": "Logo Score is less than 0.5, Visual Quality Score is less than 2, and Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to a complete absence of the Nike logo, extremely poor visual quality with no discernible product, and a significant mismatch with Nike's brand tone."
#     },
#     {
#       "frame_index": 148,
#       "reason": "Nike logo is absent from the original image content (ignoring annotations).",
#       "summary": "The frame is flagged because the Nike logo is not present in the visual content, despite showing a relevant product in an appropriate context. The visual quality of the product is also poor due to blur."
#     },
#     {
#       "frame_index": 157,
#       "reason": "Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to a significant mismatch with Nike's brand visual tone, despite the logo being clearly visible and the product placement being relevant."
#     },
#     {
#       "frame_index": 172,
#       "reason": "Nike logo is absent, visual quality is very poor, and the frame does not match the brand tone.",
#       "summary": "The frame is non-conformant due to the complete absence of the Nike logo, extremely poor visual quality, and a complete mismatch with the brand's visual tone."
#     },
#     {
#       "frame_index": 179,
#       "reason": "Logo is absent (0.0), visual quality is very poor (1), and brand tone does not match.",
#       "summary": "The frame is non-conforming due to the complete absence of brand elements, product, and extremely poor visual quality, failing to represent the Nike brand in any capacity."
#     },
#     {
#       "frame_index": 175,
#       "reason": "Logo Score is less than 0.5, Visual Quality Score is less than 2, and Brand Tone Match is NO.",
#       "summary": "The frame is flagged as non-compliant due to the complete absence of the brand logo, extremely poor visual quality with no product visible, and a complete mismatch with the brand's visual tone."
#     },
#     {
#       "frame_index": 136,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged due to the absence of the Nike logo as an organic brand element on a product or within the scene, despite the relevant product context and brand tone match."
#     },
#     {
#       "frame_index": 140,
#       "reason": "Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of the Nike product (sport shoes) despite the explicit indication, resulting in a very poor visual quality score for the product focus area, although the overall brand tone is matched."
#     },
#     {
#       "frame_index": 174,
#       "reason": "Logo is absent, visual quality is very poor (image is black), and brand tone does not match.",
#       "summary": "The frame is completely dark, lacking any visible Nike logo or product, resulting in a complete mismatch with the brand's visual tone and failing all key consistency metrics."
#     },
#     {
#       "frame_index": 168,
#       "reason": "Brand tone mismatch.",
#       "summary": "The frame clearly displays the Nike logo and references a relevant product category, but is flagged due to a significant mismatch with the expected dynamic and aspirational brand tone of Nike."
#     },
#     {
#       "frame_index": 181,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "summary": "This frame is flagged as a bad frame due to the complete absence of a Nike logo, extremely poor visual quality with no visible product, and a total mismatch with Nike's brand tone."
#     },
#     {
#       "frame_index": 180,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO. The frame is completely black, showing no product or brand elements.",
#       "summary": "The frame is severely non-compliant due to the complete absence of the product, logo, and any relevant visual content, resulting in a total mismatch with the brand's visual identity."
#     },
#     {
#       "frame_index": 173,
#       "reason": "Logo absent, very poor visual quality, and no brand tone conveyed.",
# ...
#           "status": "NO"
#         },
#         "visual_quality_score": {
#           "query": "Evaluate the visual quality of the product focus area: clarity, sharpness, and acceptable lighting.",
#           "score": 1,
#           "justification": "The frame is almost entirely black, with no visible product or discernible content, indicating extremely poor visual quality."
#         },
#         "brand_tone_match": {
#           "query": "Does the overall mood, composition, and color grading of the frame match the required brand tone: 'dynamic, athletic, inspiring, and clear'?",
#           "match": "NO",
#           "justification": "The frame is predominantly black and devoid of content, which does not align with Nike's dynamic, athletic, inspiring, or clear brand tone."
#         },
#         "product_placement_relevance": {
#           "query": "Is the product placed in a context relevant to the brand's identity?",
#           "match": "NO",
#           "justification": "No product is visible in the frame, making it impossible to assess product placement relevance to the brand's identity."
#         }
#       },
#       "is_flagged_bad_frame": "YES",
#       "flag_reason": "Nike logo is absent, visual quality is very poor, and the frame does not match the brand's visual tone. No product is visible.",
#       "final_summary": "This frame is flagged due to the complete absence of the Nike logo, extremely poor visual quality with no visible product, and a complete mismatch with the brand's visual tone.",
#       "frame_index": 294
#     },
#     {
#       "prompt_id": "BRAND_COHERENCE_V1",
#       "target_brand": "Nike",
#       "frame_status": "FLAGGED",
#       "metrics": {
#         "logo_presence_score": {
#           "query": "Is the 'Nike' logo clearly visible, not obscured, and recognizable in the frame?",
#           "score": 0.0,
#           "status": "NO"
#         },
#         "visual_quality_score": {
#           "query": "Evaluate the visual quality of the product focus area: clarity, sharpness, and acceptable lighting.",
#           "score": 1,
#           "justification": "The frame is almost entirely black with no discernible product or subject, resulting in very poor visual quality for evaluation."
#         },
#         "brand_tone_match": {
#           "query": "Does the overall mood, composition, and color grading of the frame match the required brand tone: 'athletic, empowering, dynamic, modern'?",
#           "match": "NO",
#           "justification": "The frame is completely black, offering no visual content or mood to align with Nike's athletic, empowering, dynamic, and modern brand tone."
#         },
#         "product_placement_relevance": {
#           "query": "Is the product placed in a context relevant to the brand's identity?",
#           "match": "NO",
#           "justification": "No product is visible in the frame, making it impossible to assess its placement relevance to the brand's identity."
#         }
#       },
#       "is_flagged_bad_frame": "YES",
#       "flag_reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "final_summary": "The frame is flagged as bad due to the complete absence of any visible product or brand elements, rendering it unsuitable for brand consistency analysis.",
#       "frame_index": 287
#     },
#     {
#       "prompt_id": "BRAND_COHERENCE_V1",
#       "target_brand": "Nike",
#       "frame_status": "FLAGGED",
#       "metrics": {
#         "logo_presence_score": {
#           "query": "Is the 'Nike' logo clearly visible, not obscured, and recognizable in the frame?",
#           "score": 0.0,
#           "status": "NO"
#         },
#         "visual_quality_score": {
#           "query": "Evaluate the visual quality of the product focus area: clarity, sharpness, and acceptable lighting.",
#           "score": 1,
#           "justification": "The image is almost entirely black, rendering any potential product or visual details completely indiscernible. There is no clarity, sharpness, or acceptable lighting."
#         },
#         "brand_tone_match": {
#           "query": "Does the overall mood, composition, and color grading of the frame match the required brand tone: 'dynamic, aspirational, and high-quality'?",
#           "match": "NO",
#           "justification": "The frame is devoid of visual content, primarily black, which fails to convey any brand tone, especially not Nike's dynamic, aspirational, or high-quality aesthetic."
#         },
#         "product_placement_relevance": {
#           "query": "Is the product placed in a context relevant to the brand's identity?",
#           "match": "NO",
#           "justification": "No product is visible in the frame to assess its placement or relevance to the brand's identity."
#         }
#       },
#       "is_flagged_bad_frame": "YES",
#       "flag_reason": "Logo score is 0.0 (less than 0.5), Visual quality score is 1 (less than 2), and Brand tone match is NO.",
#       "final_summary": "This frame is non-conformant as there is no visible Nike logo, the visual quality is extremely poor, and the complete lack of content prevents matching the brand tone or assessing product relevance.",
#       "frame_index": 298
#     },
#     {
#       "prompt_id": "BRAND_COHERENCE_V1",
#       "target_brand": "Nike",
#       "frame_status": "FLAGGED",
#       "metrics": {
#         "logo_presence_score": {
#           "query": "Is the 'Nike' logo clearly visible, not obscured, and recognizable in the frame?",
#           "score": 0.0,
#           "status": "NO"
#         },
#         "visual_quality_score": {
#           "query": "Evaluate the visual quality of the product focus area: clarity, sharpness, and acceptable lighting.",
#           "score": 1,
#           "justification": "The entire image is black with no visible product or subject, making it impossible to assess clarity, sharpness, or lighting."
#         },
#         "brand_tone_match": {
#           "query": "Does the overall mood, composition, and color grading of the frame match the required brand tone: 'dynamic, aspirational, athletic, modern, clean, high-energy'?",
#           "match": "NO",
#           "justification": "The frame is completely black and devoid of any visual content, therefore it cannot convey any mood, composition, or color grading that matches Nike's dynamic and athletic brand tone."
#         },
#         "product_placement_relevance": {
#           "query": "Is the product placed in a context relevant to the brand's identity?",
#           "match": "NO",
#           "justification": "There is no product visible in the frame to assess its placement or relevance."
#         }
#       },
#       "is_flagged_bad_frame": "YES",
#       "flag_reason": "Nike logo is absent (score 0.0), visual quality is very poor (score 1) due to no visible content, and the frame does not match the brand tone.",
#       "final_summary": "The frame is completely black, containing no visible Nike logo, product, or any visual elements that align with Nike's brand tone, resulting in a flagged status.",
#       "frame_index": 302
#     },
#     {
#       "prompt_id": "BRAND_COHERENCE_V1",
#       "target_brand": "Nike",
#       "frame_status": "FLAGGED",
#       "metrics": {
#         "logo_presence_score": {
#           "query": "Is the 'Nike' logo clearly visible, not obscured, and recognizable in the frame?",
#           "score": 0.0,
#           "status": "NO"
#         },
#         "visual_quality_score": {
#           "query": "Evaluate the visual quality of the product focus area: clarity, sharpness, and acceptable lighting.",
#           "score": 1,
#           "justification": "The image is almost entirely black, with no visible product or discernible content, making visual quality extremely poor."
#         },
#         "brand_tone_match": {
#           "query": "Does the overall mood, composition, and color grading of the frame match the required brand tone: 'athleticism, empowerment, performance, innovation'?",
#           "match": "NO",
#           "justification": "The frame is completely dark and devoid of any visual content, offering no mood, composition, or color grading that aligns with Nike's brand tone."
#         },
#         "product_placement_relevance": {
#           "query": "Is the product placed in a context relevant to the brand's identity?",
#           "match": "NO",
#           "justification": "There is no product visible in the frame, so relevance to the brand's identity cannot be assessed."
#         }
#       },
#       "is_flagged_bad_frame": "YES",
#       "flag_reason": "Logo Score is less than 0.5, Visual Quality Score is less than 2, and Brand Tone Match is NO.",
#       "final_summary": "This frame is flagged as bad due to the complete absence of a Nike logo, extremely poor visual quality with no visible product, and a total mismatch with the brand's visual tone.",
#       "frame_index": 304
#     },
#     {
#       "prompt_id": "BRAND_COHERENCE_V1",
#       "target_brand": "Nike",
#       "frame_status": "FLAGGED",
#       "metrics": {
#         "logo_presence_score": {
#           "query": "Is the 'Nike' logo clearly visible, not obscured, and recognizable in the frame?",
#           "score": 0.0,
#           "status": "NO"
#         },
#         "visual_quality_score": {
#           "query": "Evaluate the visual quality of the product focus area: clarity, sharpness, and acceptable lighting.",
#           "score": 1,
#           "justification": "The frame is almost entirely black with no discernible product or subject matter, resulting in very poor visual quality."
#         },
#         "brand_tone_match": {
#           "query": "Does the overall mood, composition, and color grading of the frame match the required brand tone: 'dynamic, energetic, inspiring, athletic, modern'?",
#           "match": "NO",
#           "justification": "The frame, being almost entirely black and devoid of content, completely fails to convey Nike's dynamic, energetic, or inspiring brand tone."
#         },
#         "product_placement_relevance": {
#           "query": "Is the product placed in a context relevant to the brand's identity?",
#           "match": "NO",
#           "justification": "There is no product visible in the frame, making it impossible to assess placement relevance."
#         }
#       },
#       "is_flagged_bad_frame": "YES",
#       "flag_reason": "Logo score is 0.0 (less than 0.5), Visual Quality Score is 1 (less than 2), and Brand Tone Match is NO.",
#       "final_summary": "The frame is non-compliant as it lacks any discernible Nike product or logo, exhibits very poor visual quality, and fails to align with the brand's visual tone.",
#       "frame_index": 305
#     },
#     {
#       "prompt_id": "BRAND_COHERENCE_V1",
#       "target_brand": "Nike",
#       "frame_status": "FLAGGED",
#       "metrics": {
#         "logo_presence_score": {
#           "query": "Is the 'Nike' logo clearly visible, not obscured, and recognizable in the frame?",
#           "score": 0.0,
#           "status": "NO"
#         },
#         "visual_quality_score": {
#           "query": "Evaluate the visual quality of the product focus area: clarity, sharpness, and acceptable lighting.",
#           "score": 1,
#           "justification": "The image is almost entirely black, with no discernible product or subject. Clarity, sharpness, and lighting are non-existent or extremely poor."
#         },
#         "brand_tone_match": {
#           "query": "Does the overall mood, composition, and color grading of the frame match the required brand tone: 'athletic, dynamic, performance-driven, modern, inspiring, energetic'?",
#           "match": "NO",
#           "justification": "The frame is completely dark and conveys no specific mood, composition, or color grading, thereby failing to match Nike's active and inspiring brand tone."
#         },
#         "product_placement_relevance": {
#           "query": "Is the product placed in a context relevant to the brand's identity?",
#           "match": "NO",
#           "justification": "No product is visible in the frame, making it impossible to assess its placement relevance to the brand's identity."
#         }
#       },
#       "is_flagged_bad_frame": "YES",
#       "flag_reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "final_summary": "The frame is flagged as bad due to the complete absence of a visible logo or product, extremely poor visual quality, and a significant mismatch with Nike's brand tone.",
#       "frame_index": 303
#     },
#     {
#       "prompt_id": "BRAND_COHERENCE_V1",
#       "target_brand": "Nike",
#       "frame_status": "FLAGGED",
#       "metrics": {
#         "logo_presence_score": {
#           "query": "Is the 'Nike' logo clearly visible, not obscured, and recognizable in the frame?",
#           "score": "0.0",
#           "status": "NO"
#         },
#         "visual_quality_score": {
#           "query": "Evaluate the visual quality of the product focus area: clarity, sharpness, and acceptable lighting.",
#           "score": "1",
#           "justification": "The image is almost entirely black, rendering any potential product completely indiscernible. There is no clarity, sharpness, or acceptable lighting."
#         },
#         "brand_tone_match": {
#           "query": "Does the overall mood, composition, and color grading of the frame match the required brand tone: 'dynamic, athletic, inspiring, and clear'?",
#           "match": "NO",
#           "justification": "The extreme darkness and lack of any discernible content or context do not align with Nike's active, inspiring, and clear brand aesthetic."
#         },
#         "product_placement_relevance": {
#           "query": "Is the product placed in a context relevant to the brand's identity?",
#           "match": "NO",
#           "justification": "No product is visible due to the image being almost entirely black, thus its placement relevance cannot be determined and the context is irrelevant to Nike's brand identity."
#         }
#       },
#       "is_flagged_bad_frame": "YES",
#       "flag_reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "final_summary": "This frame is flagged as bad due to the complete absence of a discernible logo or product, extremely poor visual quality, and a profound mismatch with Nike's brand tone.",
#       "frame_index": 306
#     },
#     {
#       "prompt_id": "BRAND_COHERENCE_V1",
#       "target_brand": "Nike",
#       "frame_status": "OK",
#       "metrics": {
#         "logo_presence_score": {
#           "query": "Is the 'Nike' logo clearly visible, not obscured, and recognizable in the frame?",
#           "score": "1.0",
#           "status": "YES"
#         },
#         "visual_quality_score": {
#           "query": "Evaluate the visual quality of the product focus area: clarity, sharpness, and acceptable lighting.",
#           "score": "3",
#           "justification": "The area highlighted by the annotation, corresponding to the person's lower face, lacks optimal sharpness and detail, though lighting is acceptable."
#         },
#         "brand_tone_match": {
#           "query": "Does the overall mood, composition, and color grading of the frame match the required brand tone: 'energetic, athletic, dynamic, inspiring, urban, modern'?",
#           "match": "YES",
#           "justification": "The urban setting and bright, dynamic composition align with Nike's modern and aspirational brand imagery."
#         },
#         "product_placement_relevance": {
#           "query": "Is the product placed in a context relevant to the brand's identity?",
#           "match": "NO",
#           "justification": "The annotation indicates 'sport shoes' but the bounding box is placed incongruously on the subject's face/neck, not on an actual product or its expected location."
#         }
#       },
#       "is_flagged_bad_frame": "NO",
#       "flag_reason": "None",
#       "final_summary": "The frame demonstrates good brand tone alignment and clear logo visibility (as an annotation), but exhibits a significant discrepancy in product placement where 'sport shoes' are incorrectly annotated on the subject's face.",
#       "frame_index": 235
#     }
#   ]
# }

# %%
print(json.dumps(final_compiled_json_report, indent=2))
# Out:
# {
#   "analysis_summary": {
#     "total_frames_analyzed": 307,
#     "total_flagged_frames": 194,
#     "average_logo_score": 0.43534201954397395,
#     "average_quality_score": 1.9022801302931596
#   },
#   "flagged_frames_details": [
#     {
#       "frame_index": 28,
#       "reason": "Logo is absent, visual quality is very poor, and brand tone does not match.",
#       "summary": "This frame is non-conforming as the Nike logo is absent, visual quality is extremely poor, and the overall ambiance and product context do not align with the brand's identity."
#     },
#     {
#       "frame_index": 11,
#       "reason": "Logo Score is less than 0.5 and Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo and extremely poor visual quality of the product, despite relevant product placement and brand tone match."
#     },
#     {
#       "frame_index": 20,
#       "reason": "Logo Score is less than 0.5 and Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of the brand logo and very poor visual quality of the product caused by excessive motion blur, despite depicting a relevant athletic context."
#     },
#     {
#       "frame_index": 29,
#       "reason": "Nike logo is absent, and the visual quality of the runner is very poor due to motion blur.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo and very poor visual quality of the runner because of motion blur, despite the relevant athletic context."
#     },
#     {
#       "frame_index": 23,
#       "reason": "Logo not visible, visual quality is very poor due to motion blur, and the resulting image quality does not match the brand's visual tone.",
#       "summary": "The frame is flagged as bad due to the complete absence of a visible Nike logo, extremely poor visual quality from motion blur, and a resulting mismatch with the brand's desired tone, despite the relevant product context."
#     },
#     {
#       "frame_index": 24,
#       "reason": "Logo Score is less than 0.5 and Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of a visible Nike logo and extremely poor visual quality, although the athletic context is relevant to the brand."
#     },
#     {
#       "frame_index": 5,
#       "reason": "Brand Tone Mismatch",
#       "summary": "The frame is flagged as it fails to match Nike's energetic brand tone, despite the logo being clearly visible and the product context being relevant."
#     },
#     {
#       "frame_index": 10,
#       "reason": "None",
#       "summary": "The frame is compliant, featuring a clearly visible Nike logo on relevant athletic wear within an appropriate active urban context, despite moderate visual clarity."
#     },
#     {
#       "frame_index": 27,
#       "reason": "Nike logo is absent and the visual quality of the product is very poor due to extreme motion blur.",
#       "summary": "The frame is flagged as bad due to the complete absence of the Nike logo and extremely poor visual quality of the product, despite the relevant athletic context."
#     },
#     {
#       "frame_index": 14,
#       "reason": "Logo Score is less than 0.5: The Nike logo is not clearly visible or recognizable on the sport shoes.",
#       "summary": "The frame depicts a context relevant to Nike's brand tone and product placement, but it is flagged because the Nike logo is not clearly visible on the sport shoes."
#     },
#     {
#       "frame_index": 25,
#       "reason": "Logo Score is less than 0.5 and Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the unrecognizable brand logo and very poor visual quality of the product focus area, despite the relevant athletic context."
#     },
#     {
#       "frame_index": 21,
#       "reason": "Logo Score is less than 0.5, Visual Quality Score is less than 2, and Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to the complete absence of a visible logo, extremely poor visual quality from severe motion blur, and a resultant mismatch with Nike's desired brand tone."
#     },
#     {
#       "frame_index": 22,
#       "reason": "Logo score is below 0.5, visual quality score is below 2, and brand tone match is NO.",
#       "summary": "This frame is flagged because the Nike logo is absent, the visual quality is very poor with significant blur, and the brand's dynamic tone cannot be effectively conveyed."
#     },
#     {
#       "frame_index": 4,
#       "reason": "Brand tone does not match.",
#       "summary": "The frame is flagged as the overall mood and composition do not align with Nike's typical brand tone, despite good logo visibility and relevant product context."
#     },
#     {
#       "frame_index": 9,
#       "reason": "Brand tone mismatch due to low visual quality and the presence of distracting AI-generated elements that do not reflect Nike's brand standards.",
#       "summary": "The frame is flagged due to a significant mismatch with Nike's brand tone, primarily caused by poor visual quality and the presence of distracting AI-generated elements, despite a clearly visible logo and relevant product placement."
#     },
#     {
#       "frame_index": 18,
#       "reason": "Logo Score is 0.0 (less than 0.5) and Brand Tone Match is NO due to the presence of a non-Nike brand logo.",
#       "summary": "The frame is flagged as non-conformant because the Nike logo is absent, and a different brand's logo is prominently featured, leading to a mismatch in brand tone and product relevance."
#     },
#     {
#       "frame_index": 12,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged because no Nike logo is clearly visible on the sport shoes, despite the product placement and visual tone being highly relevant to the brand."
#     },
#     {
#       "frame_index": 15,
#       "reason": "Nike logo is not clearly visible or recognizable on the product.",
#       "summary": "The frame is flagged because the Nike logo is not clearly visible on the product, despite good visual quality, relevant product placement, and a matching brand tone."
#     },
#     {
#       "frame_index": 6,
#       "reason": "Brand Tone Match is NO, and Product Placement Relevance is NO.",
#       "summary": "The frame is flagged due to a mismatch with Nike's brand tone and product placement relevance, as the static building context and limiting text 'only sport shoes' do not align with the brand's dynamic and comprehensive athletic identity."
#     },
#     {
#       "frame_index": 19,
#       "reason": "Logo score is below 0.5, visual quality score is below 2, and brand tone match is NO.",
#       "summary": "The frame is flagged due to an unrecognizable logo, extremely poor visual quality for product presentation, and a significant mismatch with Nike's established brand tone."
#     },
#     {
#       "frame_index": 7,
#       "reason": "None",
#       "summary": "The frame demonstrates strong brand coherence with a perfectly visible Nike logo and highly relevant product messaging, effectively communicating the brand's identity."
#     },
#     {
#       "frame_index": 37,
#       "reason": "Logo Score is less than 0.5 AND Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo and the very poor visual quality of the product, though the context and brand tone are appropriate."
#     },
#     {
#       "frame_index": 46,
#       "reason": "Logo Score is less than 0.5, Visual Quality Score is less than 2, and Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to the complete absence of a discernible Nike logo, extremely poor visual quality, and a lack of alignment with Nike's brand tone, rendering it non-compliant."
#     },
#     {
#       "frame_index": 31,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame depicts a relevant active context for Nike but is flagged due to the complete absence of the brand logo and poor visual quality of the product focus area."
#     },
#     {
#       "frame_index": 38,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged due to the complete absence of a visible Nike logo, despite the athletic context being highly relevant and aligning with the brand's tone."
#     },
#     {
#       "frame_index": 33,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame depicts a relevant active outdoor context for athletic footwear but is flagged due to the complete absence of any visible Nike logo, preventing brand identification."
#     },
#     {
#       "frame_index": 42,
#       "reason": "Logo Score is less than 0.5 and Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of a visible Nike logo and the extremely poor visual quality of the product area, despite the relevant active context aligning with the brand tone."
#     },
#     {
#       "frame_index": 52,
#       "reason": "Logo Score is less than 0.5, Visual Quality Score is less than 2, and Brand Tone Match is NO.",
#       "summary": "The frame is flagged as bad due to the complete absence of a visible Nike logo, extremely poor visual quality, and a significant mismatch with the brand's energetic tone."
#     },
#     {
#       "frame_index": 36,
#       "reason": "Visual quality score of the product focus area is less than 2 due to severe motion blur.",
#       "summary": "The frame is flagged due to very poor visual quality of the product, which is severely blurred despite the strong alignment with Nike's active brand tone and relevant product placement."
#     },
#     {
#       "frame_index": 43,
#       "reason": "Nike logo is absent, visual quality is very poor (score 1), and the frame's mood does not match Nike's brand tone.",
#       "summary": "This frame is flagged due to the complete absence of Nike branding, extremely poor visual quality, and a complete mismatch with Nike's brand tone and product relevance."
#     },
#     {
#       "frame_index": 39,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame effectively conveys an active context relevant to Nike's brand identity, but it is flagged due to the complete absence of a visible Nike logo and the poor visual quality of the product."
#     },
#     {
#       "frame_index": 44,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo and extremely poor visual quality, though the dynamic motion blur aligns with the brand's tone."
#     },
#     {
#       "frame_index": 45,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "summary": "The frame is flagged as bad due to the complete absence of a visible Nike logo, very poor visual quality of the product, and a mismatch with Nike's dynamic brand tone, despite the product being in a relevant athletic context."
#     },
#     {
#       "frame_index": 40,
#       "reason": "Nike logo not visible (score < 0.5) and very poor visual quality of the product area (score < 2).",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo and very poor visual quality of the product area, despite the relevant athletic context."
#     },
#     {
#       "frame_index": 55,
#       "reason": "Nike logo is not clearly visible, and the visual quality of the product focus area is very poor.",
#       "summary": "The frame is flagged due to the absence of a discernible Nike logo and very poor visual quality of the product focus area, despite the relevant product placement and brand tone match."
#     },
#     {
#       "frame_index": 47,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo, despite the textual content and overall aesthetic being highly relevant to the brand's identity."
#     },
#     {
#       "frame_index": 49,
#       "reason": "Nike logo is absent, visual quality is poor, and the brand tone does not match Nike's identity.",
#       "summary": "The frame is flagged as bad due to the complete absence of any Nike logo, poor visual quality, and a scene that fails to align with Nike's brand tone and product context relevance."
#     },
#     {
#       "frame_index": 34,
#       "reason": "None",
#       "summary": "The frame is coherent with the Nike brand, effectively showing the product in an active context, despite the visual quality being compromised by motion blur."
#     },
#     {
#       "frame_index": 50,
#       "reason": "Logo Score is less than 0.5, Visual Quality Score is less than 2, Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to the complete absence of a discernible Nike logo, extremely poor visual quality of the product focus, and a mismatch with the brand's aspirational tone."
#     },
#     {
#       "frame_index": 51,
#       "reason": "Logo Score is 0.0 (less than 0.5); Visual Quality Score is 1 (less than 2); Brand Tone Match is NO.",
#       "summary": "This frame is flagged as bad due to the complete absence of any discernible Nike logo, extremely poor visual quality, and a significant mismatch with Nike's brand tone and product placement relevance."
#     },
#     {
#       "frame_index": 41,
#       "reason": "Logo Score is 0.1, which is less than the threshold of 0.5.",
#       "summary": "The frame is flagged because the Nike logo is not clearly visible on the product, despite the strong relevance of the athletic context and brand tone match."
#     },
#     {
#       "frame_index": 30,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "summary": "The frame is flagged as non-compliant due to the complete absence of any Nike logo or product, extremely poor visual quality, and a significant mismatch with Nike's brand tone."
#     },
#     {
#       "frame_index": 32,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged due to the absence of a clearly visible Nike logo, despite the strong relevance of the product placement and alignment with the brand's dynamic tone."
#     },
#     {
#       "frame_index": 48,
#       "reason": "Logo Score is less than 0.5 and Brand Tone Match is NO.",
#       "summary": "The frame is non-compliant as no Nike product or logo is visible, and the overall visual tone does not match the brand's athletic and inspiring aesthetic."
#     },
#     {
#       "frame_index": 53,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of any discernible Nike logo and very poor visual quality, despite the context being relevant to the brand's tone and product placement."
#     },
#     {
#       "frame_index": 57,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged because the Nike logo is not clearly visible or recognizable, despite relevant product placement and brand tone match."
#     },
#     {
#       "frame_index": 60,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged due to the complete absence of any visible Nike logo, despite the product being relevantly placed in an athletic context that aligns with the brand's tone."
#     },
#     {
#       "frame_index": 58,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged because the Nike logo is completely absent, although the visual tone and product context are relevant to the brand."
#     },
#     {
#       "frame_index": 59,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged due to the absence of a clearly visible or recognizable Nike logo, despite depicting a context highly relevant to the brand's identity and having an appropriate brand tone."
#     },
#     {
#       "frame_index": 64,
#       "reason": "Logo is absent, visual quality is very poor, and the brand tone does not match Nike's identity.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo, very poor visual quality, and a significant mismatch with the brand's visual tone, with no product visible."
#     },
#     {
#       "frame_index": 61,
#       "reason": "Logo not visible and very poor visual quality of the product focus area.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo and very poor visual quality, despite the context being relevant to the brand."
#     },
#     {
#       "frame_index": 66,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "summary": "The frame is flagged as bad due to the complete absence of the Nike logo, extremely poor visual quality, and a total mismatch with the brand's visual tone and identity."
#     },
#     {
#       "frame_index": 62,
#       "reason": "Logo is absent and visual quality is very poor due to severe motion blur on the main subject.",
#       "summary": "The frame is flagged due to the complete absence of a visible Nike logo and very poor visual quality of the product focus area, despite good brand tone and product placement relevance."
#     },
#     {
#       "frame_index": 63,
#       "reason": "Logo Score is less than 0.5 and Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of a visible Nike logo and very poor visual quality of the subject, despite the context being relevant to the brand's active tone."
#     },
#     {
#       "frame_index": 69,
#       "reason": "Logo score is less than 0.5, visual quality score is less than 2, and brand tone match is NO.",
#       "summary": "This frame is flagged due to the complete absence of a visible Nike logo, extremely poor visual quality caused by motion blur, and the inability of the image to effectively convey the brand's intended athletic and energetic tone."
#     },
#     {
#       "frame_index": 72,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame captures an athletic aesthetic in an urban setting consistent with Nike's brand tone, but it is flagged as the Nike logo is entirely absent, making brand product identification impossible."
#     },
#     {
#       "frame_index": 67,
#       "reason": "Logo is absent, visual quality is very poor due to extreme blur, and the severe blur compromises the effective communication of the brand tone.",
#       "summary": "The frame is flagged due to very poor visual quality, the absence of a visible logo, and the inability to effectively convey the brand's tone despite a relevant product context."
#     },
#     {
#       "frame_index": 75,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "This frame is flagged for brand inconsistency due to the complete absence of the Nike logo, despite the product context and brand tone being highly relevant."
#     },
#     {
#       "frame_index": 65,
#       "reason": "Logo Score is less than 0.5 and Brand Tone Match is NO.",
#       "summary": "This frame is flagged as bad due to the complete absence of any Nike branding or product, and the overall scene fails to align with Nike's brand tone."
#     },
#     {
#       "frame_index": 68,
#       "reason": "Nike logo is absent from the frame.",
#       "summary": "The frame is flagged because the Nike logo is completely absent, although the product placement is relevant to the brand's identity, the visual quality is poor."
#     },
#     {
#       "frame_index": 81,
#       "reason": "Nike logo is absent.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo, despite otherwise good brand tone match and product placement relevance."
#     },
#     {
#       "frame_index": 71,
#       "reason": "The Nike logo is entirely absent, and a different brand's logo is prominently displayed on the product.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo, despite the visual quality, brand tone, and product placement context being otherwise suitable for an athletic brand."
#     },
#     {
#       "frame_index": 74,
#       "reason": "Logo Score is less than 0.5, Visual Quality Score is less than 2, and Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo, very poor visual quality marked by significant blurriness, and a brand tone that does not cohere with Nike's typical high-quality aesthetic."
#     },
#     {
#       "frame_index": 73,
#       "reason": "Nike logo is absent.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo, despite an otherwise relevant brand tone and context."
#     },
#     {
#       "frame_index": 82,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged due to the complete absence of a recognizable Nike logo and poor visual quality, despite matching the brand's tone and product placement relevance."
#     },
#     {
#       "frame_index": 78,
#       "reason": "Nike logo is absent from the frame.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo, despite the visual tone and product placement being highly relevant to the brand."
#     },
#     {
#       "frame_index": 85,
#       "reason": "Logo Score is less than 0.5 and Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of a clearly recognizable Nike logo and very poor visual quality, despite the athletic product placement and relevant brand tone."
#     },
#     {
#       "frame_index": 87,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo, extremely poor visual quality, and a generic, dark context that does not align with the brand's tone or identity."
#     },
#     {
#       "frame_index": 86,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to the complete absence of a visible logo, extremely poor visual quality, and a significant mismatch with the brand's visual tone."
#     },
#     {
#       "frame_index": 80,
#       "reason": "Nike logo is completely absent, and other brand logos ('QUARTERMILE' and a distinct jacket logo) are visible instead.",
#       "summary": "The frame is flagged because the Nike logo is entirely absent, and other brand identifiers are present, failing to represent the target brand's product, despite matching visual tone and product context."
#     },
#     {
#       "frame_index": 79,
#       "reason": "Nike logo is absent, and a competing brand ('Quartermile') is visibly featured, leading to a logo score below 0.5 and a mismatch in brand tone.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo and the clear presence of branding for another company, 'Quartermile', which directly contradicts the target brand."
#     },
#     {
#       "frame_index": 89,
#       "reason": "Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to a significant mismatch with Nike's brand tone, despite the logo being clearly visible and product placement being relevant."
#     },
#     {
#       "frame_index": 84,
#       "reason": "Logo Score is less than 0.5 and Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of a visible Nike logo and very poor visual quality, despite the product being placed in a relevant athletic urban context that generally aligns with the brand's tone."
#     },
#     {
#       "frame_index": 88,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to an absent logo, very poor visual quality, and a complete mismatch with Nike's brand tone and product placement relevance."
#     },
#     {
#       "frame_index": 76,
#       "reason": "Nike logo is absent (score 0.0). The frame also explicitly features other brand names and logos, promoting non-Nike products.",
#       "summary": "The frame is flagged due to the complete absence of Nike branding and the presence of other brand logos, making it inconsistent with brand guidelines despite the visual tone being aligned with Nike's aesthetic."
#     },
#     {
#       "frame_index": 96,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo, despite the product placement being relevant and the overall tone aligning with the brand."
#     },
#     {
#       "frame_index": 90,
#       "reason": "Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the poor visual quality and lack of sharpness of the product (shoes), despite the logo being clear and context relevant to the brand."
#     },
#     {
#       "frame_index": 110,
#       "reason": "None",
#       "summary": "The frame is highly consistent with the Nike Running brand, featuring a clear logo, good visual quality, and relevant product placement in an appropriate active urban setting."
#     },
#     {
#       "frame_index": 94,
#       "reason": "Logo Score is less than 0.5, as the Nike logo is not clearly visible or recognizable.",
#       "summary": "The frame is flagged due to the Nike logo being virtually absent and unrecognizable, despite the overall tone and product placement being relevant to the brand."
#     },
#     {
#       "frame_index": 93,
#       "reason": "Visual quality score is less than 2 and brand tone match is NO. Additionally, product placement is inconsistent with the brand's core product.",
#       "summary": "The frame is flagged due to very poor visual quality, a mismatch with the brand's tone, and highly inconsistent product placement where the Nike logo is present but the actual sport shoe product is absent or heavily obscured, contradicting the explicit text."
#     },
#     {
#       "frame_index": 95,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "summary": "The frame is flagged as bad due to the complete absence of the Nike logo, the poor visual quality and blurriness of the product, and a mismatch with Nike's dynamic brand tone."
#     },
#     {
#       "frame_index": 91,
#       "reason": "None",
#       "summary": "The frame is generally compliant with good visual quality and brand tone, however, the product placement is inconsistent due to bare feet being shown despite the 'only sport shoes' label."
#     },
#     {
#       "frame_index": 111,
#       "reason": "None",
#       "summary": "The frame is highly conformant, showcasing clear Nike branding with relevant product placement and a visual tone consistent with the brand's athletic and modern identity."
#     },
#     {
#       "frame_index": 103,
#       "reason": "None",
#       "summary": "The frame conforms with clear logo presence, good brand tone, and relevant product placement, though the visual quality of the product focus area is notably blurry."
#     },
#     {
#       "frame_index": 121,
#       "reason": "None",
#       "summary": "The frame is consistent with the Nike Running brand, showcasing a clearly visible logo and a relevant, well-executed visual context that aligns with the brand's dynamic and authentic tone."
#     },
#     {
#       "frame_index": 127,
#       "reason": "None",
#       "summary": "The frame fully conforms to brand guidelines, featuring a clear Nike logo and highly relevant context for its running segment with good visual quality and brand tone match."
#     },
#     {
#       "frame_index": 123,
#       "reason": "None",
#       "summary": "The frame is fully compliant with Nike's brand guidelines, showcasing clear branding, good visual quality, and an energetic, relevant context."
#     },
#     {
#       "frame_index": 128,
#       "reason": "None",
#       "summary": "The frame is highly conformant with Nike's brand guidelines, featuring clear branding, good visual quality, and a highly relevant context that aligns with the brand's tone."
#     },
#     {
#       "frame_index": 135,
#       "reason": "Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to a significant mismatch with Nike's established brand tone, despite clear logo presence and relevant product context."
#     },
#     {
#       "frame_index": 145,
#       "reason": "None",
#       "summary": "The frame shows good brand coherence with a clearly visible Nike logo and relevant product placement, despite some blurriness affecting overall visual quality."
#     },
#     {
#       "frame_index": 137,
#       "reason": "Logo Score is less than 0.5 and Brand Tone Match is NO.",
#       "summary": "The frame is flagged as non-compliant due to the complete absence of any visible Nike logo or product within the scene and a significant mismatch with Nike's characteristic dynamic brand tone."
#     },
#     {
#       "frame_index": 134,
#       "reason": "Visual Quality Score is 1 (less than 2) and Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to very poor visual quality caused by heavy pixelation and a digital glitch effect, and a significant mismatch with Nike's typical brand tone, despite clear logo presence and relevant product placement."
#     },
#     {
#       "frame_index": 99,
#       "reason": "None",
#       "summary": "The frame conforms to brand consistency, effectively showcasing a Nike sport shoe in a relevant urban context with a clear brand logo and appropriate visual tone, despite the product's stylized rendering."
#     },
#     {
#       "frame_index": 153,
#       "reason": "Brand Tone Mismatch",
#       "summary": "The frame is flagged as bad due to a significant mismatch with Nike's brand tone, despite the logo being clearly visible and the product being relevant."
#     },
#     {
#       "frame_index": 152,
#       "reason": "None",
#       "summary": "The frame is coherent with the Nike brand, effectively featuring the logo on a product in an active context, despite moderate blurriness in visual quality."
#     },
#     {
#       "frame_index": 138,
#       "reason": "Brand tone mismatch and absence of actual product placement in the scene.",
#       "summary": "The frame is flagged due to a significant mismatch with Nike's brand tone, characterized by low visual quality and a lack of dynamic energy, coupled with the absence of a physically placed Nike product in the scene."
#     },
#     {
#       "frame_index": 143,
#       "reason": "Brand Tone Match is NO.",
#       "summary": "The frame is flagged because its visual tone and low quality do not align with the Nike brand's identity, despite clear logo presence and relevant product placement."
#     },
#     {
#       "frame_index": 154,
#       "reason": "Brand Tone Match is NO.",
#       "summary": "The frame is flagged because the overall mood and visual quality do not match Nike's required brand tone, despite the logo being clearly visible and product placement being relevant."
#     },
#     {
#       "frame_index": 155,
#       "reason": "Brand Tone Match is NO.",
#       "summary": "The frame correctly identifies the Nike logo on a relevant product but is flagged due to the blurry visual quality and a brand tone that does not align with Nike's energetic aesthetic."
#     },
#     {
#       "frame_index": 149,
#       "reason": "Logo Score is less than 0.5. The Nike logo is not clearly visible or recognizable on the product.",
#       "summary": "This frame is flagged because the Nike logo on the product is not clearly visible, despite the product being in a relevant context and portraying an appropriate brand tone."
#     },
#     {
#       "frame_index": 159,
#       "reason": "Brand Tone Mismatch",
#       "summary": "The frame is flagged due to a significant mismatch in brand tone, despite the Nike logo being clearly visible and the product context being relevant."
#     },
#     {
#       "frame_index": 160,
#       "reason": "Brand Tone Mismatch",
#       "summary": "The frame displays a clear Nike logo with relevant product text, but the severe lack of visual context and poor lighting prevent it from matching Nike's characteristic energetic brand tone, leading to a flagged frame."
#     },
#     {
#       "frame_index": 158,
#       "reason": "Brand tone mismatch.",
#       "summary": "The frame is flagged due to a significant mismatch with Nike's energetic brand tone, as the image is overly dark and lacks dynamism, despite the clear presence of the Nike logo on a relevant product."
#     },
#     {
#       "frame_index": 166,
#       "reason": "None",
#       "summary": "The frame is highly conformant with the brand's visual identity, featuring a clear logo and a message directly relevant to Nike's core product category."
#     },
#     {
#       "frame_index": 167,
#       "reason": "None",
#       "summary": "The frame is highly coherent with the Nike brand, displaying a clear logo and a message directly relevant to its core product, all with excellent visual quality."
#     },
#     {
#       "frame_index": 177,
#       "reason": "Logo Score is less than 0.5, Visual Quality Score is less than 2, and Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to a complete absence of the Nike logo, extremely poor visual quality with no discernible product, and a significant mismatch with Nike's brand tone."
#     },
#     {
#       "frame_index": 148,
#       "reason": "Nike logo is absent from the original image content (ignoring annotations).",
#       "summary": "The frame is flagged because the Nike logo is not present in the visual content, despite showing a relevant product in an appropriate context. The visual quality of the product is also poor due to blur."
#     },
#     {
#       "frame_index": 157,
#       "reason": "Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to a significant mismatch with Nike's brand visual tone, despite the logo being clearly visible and the product placement being relevant."
#     },
#     {
#       "frame_index": 172,
#       "reason": "Nike logo is absent, visual quality is very poor, and the frame does not match the brand tone.",
#       "summary": "The frame is non-conformant due to the complete absence of the Nike logo, extremely poor visual quality, and a complete mismatch with the brand's visual tone."
#     },
#     {
#       "frame_index": 179,
#       "reason": "Logo is absent (0.0), visual quality is very poor (1), and brand tone does not match.",
#       "summary": "The frame is non-conforming due to the complete absence of brand elements, product, and extremely poor visual quality, failing to represent the Nike brand in any capacity."
#     },
#     {
#       "frame_index": 175,
#       "reason": "Logo Score is less than 0.5, Visual Quality Score is less than 2, and Brand Tone Match is NO.",
#       "summary": "The frame is flagged as non-compliant due to the complete absence of the brand logo, extremely poor visual quality with no product visible, and a complete mismatch with the brand's visual tone."
#     },
#     {
#       "frame_index": 136,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged due to the absence of the Nike logo as an organic brand element on a product or within the scene, despite the relevant product context and brand tone match."
#     },
#     {
#       "frame_index": 140,
#       "reason": "Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to the complete absence of the Nike product (sport shoes) despite the explicit indication, resulting in a very poor visual quality score for the product focus area, although the overall brand tone is matched."
#     },
#     {
#       "frame_index": 174,
#       "reason": "Logo is absent, visual quality is very poor (image is black), and brand tone does not match.",
#       "summary": "The frame is completely dark, lacking any visible Nike logo or product, resulting in a complete mismatch with the brand's visual tone and failing all key consistency metrics."
#     },
#     {
#       "frame_index": 168,
#       "reason": "Brand tone mismatch.",
#       "summary": "The frame clearly displays the Nike logo and references a relevant product category, but is flagged due to a significant mismatch with the expected dynamic and aspirational brand tone of Nike."
#     },
#     {
#       "frame_index": 181,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "summary": "This frame is flagged as a bad frame due to the complete absence of a Nike logo, extremely poor visual quality with no visible product, and a total mismatch with Nike's brand tone."
#     },
#     {
#       "frame_index": 180,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO. The frame is completely black, showing no product or brand elements.",
#       "summary": "The frame is severely non-compliant due to the complete absence of the product, logo, and any relevant visual content, resulting in a total mismatch with the brand's visual identity."
#     },
#     {
#       "frame_index": 173,
#       "reason": "Logo absent, very poor visual quality, and no brand tone conveyed.",
#       "summary": "The frame is flagged as bad due to the complete absence of the Nike logo, extremely poor visual quality with no discernible content, and a total mismatch with Nike's brand tone."
#     },
#     {
#       "frame_index": 165,
#       "reason": "Brand Tone Match is NO.",
#       "summary": "While the Nike logo is clearly present and relevant, the frame is flagged because its minimalist composition and informational tone do not align with Nike's dynamic and aspirational brand tone."
#     },
#     {
#       "frame_index": 178,
#       "reason": "No discernible logo, extremely poor visual quality due to underexposure, and complete mismatch with the brand's visual tone.",
#       "summary": "This frame is non-compliant as it lacks any visible product or branding, presents extremely poor visual quality, and entirely fails to convey the brand's dynamic tone."
#     },
#     {
#       "frame_index": 176,
#       "reason": "The frame completely lacks visibility of any product or brand logo, leading to an inability to assess visual quality, brand tone, or product relevance. The logo is absent, visual quality is very poor, and brand tone does not match.",
#       "summary": "This frame is non-compliant as it is entirely black, rendering the Nike logo, any product, and brand tone invisible and impossible to assess against brand standards."
#     },
#     {
#       "frame_index": 183,
#       "reason": "Logo score is 0.0 (less than 0.5), Visual quality score is 1 (less than 2), and Brand tone match is NO.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo, extremely poor visual quality with no discernible product, and a fundamental mismatch with the brand's visual tone and identity."
#     },
#     {
#       "frame_index": 169,
#       "reason": "Brand Tone Match is NO.",
#       "summary": "The frame is flagged because its technical composition with detection boxes and labels does not align with a consistent brand tone, despite the Nike logo being perfectly clear and the mentioned product category being highly relevant."
#     },
#     {
#       "frame_index": 171,
#       "reason": "None",
#       "summary": "The frame generally conforms to brand consistency, with the main concern being the pixelation and stylized clarity of the logo itself."
#     },
#     {
#       "frame_index": 182,
#       "reason": "No visible logo or product, extremely poor visual quality (score 1), and a complete mismatch with the brand tone.",
#       "summary": "The frame is flagged due to the complete absence of a visible Nike logo or product, extremely poor visual quality, and a profound mismatch with the brand's visual tone."
#     },
#     {
#       "frame_index": 170,
#       "reason": "Brand Tone Match is NO",
#       "summary": "The frame is flagged due to a significant mismatch with Nike's typical brand tone, despite excellent logo visibility and highly relevant product context."
#     },
#     {
#       "frame_index": 190,
#       "reason": "None",
#       "summary": "The frame is in conformity, effectively showcasing Nike Running's brand identity with relevant product placement and a matching brand tone."
#     },
#     {
#       "frame_index": 146,
#       "reason": "Logo Score is less than 0.5. Brand Tone Match is NO.",
#       "summary": "The frame is flagged as bad due to the absence of a clearly identifiable Nike logo on the product and a mismatch with the brand's expected visual tone and quality."
#     },
#     {
#       "frame_index": 196,
#       "reason": "None",
#       "summary": "This frame demonstrates excellent brand consistency for Nike Running, with clear branding, high visual quality, and a strong match to the dynamic and urban brand tone."
#     },
#     {
#       "frame_index": 200,
#       "reason": "None",
#       "summary": "The frame fully conforms to brand guidelines, effectively communicating the Nike Running brand in a visually appealing and tonally appropriate setting."
#     },
#     {
#       "frame_index": 184,
#       "reason": "Visual Quality Score is less than 2 and Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to extremely poor visual quality and a significant mismatch with Nike's expected professional brand tone, despite the clear logo presence and relevant product context."
#     },
#     {
#       "frame_index": 206,
#       "reason": "None",
#       "summary": "The frame conforms well to brand consistency, with clearly visible branding and a visual tone that perfectly matches Nike Running's identity within a relevant context."
#     },
#     {
#       "frame_index": 210,
#       "reason": "None",
#       "summary": "The frame effectively aligns with Nike's brand identity for running, featuring clear branding in a relevant, dynamic urban setting."
#     },
#     {
#       "frame_index": 195,
#       "reason": "Visual Quality Score is less than 2, specifically due to the extremely poor rendering of the highlighted product/person focus area.",
#       "summary": "The frame effectively communicates the Nike Running brand tone and relevant context, but is flagged due to the extremely poor visual quality of the prominent product/person focus area."
#     },
#     {
#       "frame_index": 217,
#       "reason": "None",
#       "summary": "The frame exhibits strong brand consistency with a clear logo, relevant product context for Nike Running, and an atmospheric tone that matches the brand's aesthetic."
#     },
#     {
#       "frame_index": 221,
#       "reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "summary": "The frame is flagged as bad due to the complete absence of a Nike logo, extremely poor visual quality for product visibility, and an unidentifiable brand tone that does not align with Nike's messaging."
#     },
#     {
#       "frame_index": 226,
#       "reason": "Nike logo is not present in the original frame content; the visible logo is an annotation.",
#       "summary": "The frame is flagged due to the complete absence of the Nike logo within the original visual content, although other elements align with the brand's tone and context."
#     },
#     {
#       "frame_index": 203,
#       "reason": "Visual Quality Score is less than 2, as no specific Nike product is discernible.",
#       "summary": "The frame is flagged because no specific Nike product is discernible, despite the clear presence of the 'Nike Running' brand name and an overall context that aligns well with Nike Running's brand identity and tone."
#     },
#     {
#       "frame_index": 239,
#       "reason": "Visual Quality Score is 1 (Very Poor) and Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to very poor visual quality and a mismatch with Nike's brand tone, despite the logo being clearly visible and the product context being relevant."
#     },
#     {
#       "frame_index": 247,
#       "reason": "Visual Quality Score is less than 2.",
#       "summary": "The frame is flagged due to very poor visual quality, making the product difficult to discern, despite strong brand tone and product placement relevance."
#     },
#     {
#       "frame_index": 245,
#       "reason": "Visual Quality Score is less than 2.",
#       "summary": "The frame successfully places the Nike product in a relevant athletic context with a clear logo, but its extremely poor visual quality due to motion blur results in a flagged status."
#     },
#     {
#       "frame_index": 223,
#       "reason": "Logo Score is less than 0.5, Visual Quality Score is less than 2, and Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to the complete absence of an organically visible Nike logo on a product, very poor visual quality caused by digital effects, and a brand tone mismatch with Nike's typical aesthetic."
#     },
#     {
#       "frame_index": 250,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame presents a relevant athletic context, but the absence of a visible Nike logo and the poor visual quality of the product lead to a flagged status."
#     },
#     {
#       "frame_index": 248,
#       "reason": "Visual Quality Score is less than 2.",
#       "summary": "The frame aligns with Nike's brand tone and product placement but is flagged due to very poor visual quality of the product focus area."
#     },
#     {
#       "frame_index": 225,
#       "reason": "The Nike logo and product information are annotations, not organic elements of the original image. No actual Nike product is present in the frame, and therefore, product placement and brand tone match are compromised.",
#       "summary": "The frame is flagged due to the complete absence of any actual Nike product or organic brand logo within the scene, making it unsuitable for brand consistency analysis despite overlay annotations."
#     },
#     {
#       "frame_index": 230,
#       "reason": "Logo Score is less than 0.5.",
#       "summary": "The frame is flagged due to the absence of the Nike logo within the depicted scene. While the urban setting aligns with the brand's tone, the overall visual quality is only fair."
#     },
#     {
#       "frame_index": 244,
#       "reason": "Logo not visible on the product, extremely poor visual quality, and brand tone mismatch due to blur and lack of dynamism.",
#       "summary": "The frame is flagged due to the complete absence of a visible Nike logo on the product, extremely poor visual quality making the product indistinguishable, and a significant mismatch with the brand's active and dynamic tone."
#     },
#     {
#       "frame_index": 257,
#       "reason": "Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to a mismatch with Nike's energetic brand tone, despite the clear visibility of the logo and relevant product placement."
#     },
#     {
#       "frame_index": 252,
#       "reason": "None",
#       "summary": "The frame is coherent with the Nike brand, clearly showcasing the logo in a relevant, athletic context, despite moderate visual quality."
#     },
#     {
#       "frame_index": 256,
#       "reason": "Brand Tone Match is NO.",
#       "summary": "The frame features a clearly visible Nike logo on a relevant product; however, the overall dark and muted visual tone significantly mismatches Nike's characteristic energetic brand identity, resulting in a flagged frame."
#     },
#     {
#       "frame_index": 260,
#       "reason": "Visual Quality Score is less than 2 and Brand Tone Match is NO.",
#       "summary": "The frame is flagged due to very poor visual quality and a significant mismatch with Nike's energetic brand tone, despite the clear presence of the logo and relevant implied product context."
#     },
#     {
#       "frame_index": 262,
#       "reason": "Brand Tone Match is NO.",
#       "summary": "The frame clearly displays the Nike logo and identifies its product relevance, but is flagged due to a significant mismatch with Nike's expected dynamic and athletic brand tone."
#     },
#     {
#       "frame_index": 255,
#       "reason": "Visual Quality Score is less than 2 and Brand Tone Match is NO.",
# ...
#           "status": "NO"
#         },
#         "visual_quality_score": {
#           "query": "Evaluate the visual quality of the product focus area: clarity, sharpness, and acceptable lighting.",
#           "score": 1,
#           "justification": "The frame is almost entirely black, with no visible product or discernible content, indicating extremely poor visual quality."
#         },
#         "brand_tone_match": {
#           "query": "Does the overall mood, composition, and color grading of the frame match the required brand tone: 'dynamic, athletic, inspiring, and clear'?",
#           "match": "NO",
#           "justification": "The frame is predominantly black and devoid of content, which does not align with Nike's dynamic, athletic, inspiring, or clear brand tone."
#         },
#         "product_placement_relevance": {
#           "query": "Is the product placed in a context relevant to the brand's identity?",
#           "match": "NO",
#           "justification": "No product is visible in the frame, making it impossible to assess product placement relevance to the brand's identity."
#         }
#       },
#       "is_flagged_bad_frame": "YES",
#       "flag_reason": "Nike logo is absent, visual quality is very poor, and the frame does not match the brand's visual tone. No product is visible.",
#       "final_summary": "This frame is flagged due to the complete absence of the Nike logo, extremely poor visual quality with no visible product, and a complete mismatch with the brand's visual tone.",
#       "frame_index": 294
#     },
#     {
#       "prompt_id": "BRAND_COHERENCE_V1",
#       "target_brand": "Nike",
#       "frame_status": "FLAGGED",
#       "metrics": {
#         "logo_presence_score": {
#           "query": "Is the 'Nike' logo clearly visible, not obscured, and recognizable in the frame?",
#           "score": 0.0,
#           "status": "NO"
#         },
#         "visual_quality_score": {
#           "query": "Evaluate the visual quality of the product focus area: clarity, sharpness, and acceptable lighting.",
#           "score": 1,
#           "justification": "The frame is almost entirely black with no discernible product or subject, resulting in very poor visual quality for evaluation."
#         },
#         "brand_tone_match": {
#           "query": "Does the overall mood, composition, and color grading of the frame match the required brand tone: 'athletic, empowering, dynamic, modern'?",
#           "match": "NO",
#           "justification": "The frame is completely black, offering no visual content or mood to align with Nike's athletic, empowering, dynamic, and modern brand tone."
#         },
#         "product_placement_relevance": {
#           "query": "Is the product placed in a context relevant to the brand's identity?",
#           "match": "NO",
#           "justification": "No product is visible in the frame, making it impossible to assess its placement relevance to the brand's identity."
#         }
#       },
#       "is_flagged_bad_frame": "YES",
#       "flag_reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "final_summary": "The frame is flagged as bad due to the complete absence of any visible product or brand elements, rendering it unsuitable for brand consistency analysis.",
#       "frame_index": 287
#     },
#     {
#       "prompt_id": "BRAND_COHERENCE_V1",
#       "target_brand": "Nike",
#       "frame_status": "FLAGGED",
#       "metrics": {
#         "logo_presence_score": {
#           "query": "Is the 'Nike' logo clearly visible, not obscured, and recognizable in the frame?",
#           "score": 0.0,
#           "status": "NO"
#         },
#         "visual_quality_score": {
#           "query": "Evaluate the visual quality of the product focus area: clarity, sharpness, and acceptable lighting.",
#           "score": 1,
#           "justification": "The image is almost entirely black, rendering any potential product or visual details completely indiscernible. There is no clarity, sharpness, or acceptable lighting."
#         },
#         "brand_tone_match": {
#           "query": "Does the overall mood, composition, and color grading of the frame match the required brand tone: 'dynamic, aspirational, and high-quality'?",
#           "match": "NO",
#           "justification": "The frame is devoid of visual content, primarily black, which fails to convey any brand tone, especially not Nike's dynamic, aspirational, or high-quality aesthetic."
#         },
#         "product_placement_relevance": {
#           "query": "Is the product placed in a context relevant to the brand's identity?",
#           "match": "NO",
#           "justification": "No product is visible in the frame to assess its placement or relevance to the brand's identity."
#         }
#       },
#       "is_flagged_bad_frame": "YES",
#       "flag_reason": "Logo score is 0.0 (less than 0.5), Visual quality score is 1 (less than 2), and Brand tone match is NO.",
#       "final_summary": "This frame is non-conformant as there is no visible Nike logo, the visual quality is extremely poor, and the complete lack of content prevents matching the brand tone or assessing product relevance.",
#       "frame_index": 298
#     },
#     {
#       "prompt_id": "BRAND_COHERENCE_V1",
#       "target_brand": "Nike",
#       "frame_status": "FLAGGED",
#       "metrics": {
#         "logo_presence_score": {
#           "query": "Is the 'Nike' logo clearly visible, not obscured, and recognizable in the frame?",
#           "score": 0.0,
#           "status": "NO"
#         },
#         "visual_quality_score": {
#           "query": "Evaluate the visual quality of the product focus area: clarity, sharpness, and acceptable lighting.",
#           "score": 1,
#           "justification": "The entire image is black with no visible product or subject, making it impossible to assess clarity, sharpness, or lighting."
#         },
#         "brand_tone_match": {
#           "query": "Does the overall mood, composition, and color grading of the frame match the required brand tone: 'dynamic, aspirational, athletic, modern, clean, high-energy'?",
#           "match": "NO",
#           "justification": "The frame is completely black and devoid of any visual content, therefore it cannot convey any mood, composition, or color grading that matches Nike's dynamic and athletic brand tone."
#         },
#         "product_placement_relevance": {
#           "query": "Is the product placed in a context relevant to the brand's identity?",
#           "match": "NO",
#           "justification": "There is no product visible in the frame to assess its placement or relevance."
#         }
#       },
#       "is_flagged_bad_frame": "YES",
#       "flag_reason": "Nike logo is absent (score 0.0), visual quality is very poor (score 1) due to no visible content, and the frame does not match the brand tone.",
#       "final_summary": "The frame is completely black, containing no visible Nike logo, product, or any visual elements that align with Nike's brand tone, resulting in a flagged status.",
#       "frame_index": 302
#     },
#     {
#       "prompt_id": "BRAND_COHERENCE_V1",
#       "target_brand": "Nike",
#       "frame_status": "FLAGGED",
#       "metrics": {
#         "logo_presence_score": {
#           "query": "Is the 'Nike' logo clearly visible, not obscured, and recognizable in the frame?",
#           "score": 0.0,
#           "status": "NO"
#         },
#         "visual_quality_score": {
#           "query": "Evaluate the visual quality of the product focus area: clarity, sharpness, and acceptable lighting.",
#           "score": 1,
#           "justification": "The image is almost entirely black, with no visible product or discernible content, making visual quality extremely poor."
#         },
#         "brand_tone_match": {
#           "query": "Does the overall mood, composition, and color grading of the frame match the required brand tone: 'athleticism, empowerment, performance, innovation'?",
#           "match": "NO",
#           "justification": "The frame is completely dark and devoid of any visual content, offering no mood, composition, or color grading that aligns with Nike's brand tone."
#         },
#         "product_placement_relevance": {
#           "query": "Is the product placed in a context relevant to the brand's identity?",
#           "match": "NO",
#           "justification": "There is no product visible in the frame, so relevance to the brand's identity cannot be assessed."
#         }
#       },
#       "is_flagged_bad_frame": "YES",
#       "flag_reason": "Logo Score is less than 0.5, Visual Quality Score is less than 2, and Brand Tone Match is NO.",
#       "final_summary": "This frame is flagged as bad due to the complete absence of a Nike logo, extremely poor visual quality with no visible product, and a total mismatch with the brand's visual tone.",
#       "frame_index": 304
#     },
#     {
#       "prompt_id": "BRAND_COHERENCE_V1",
#       "target_brand": "Nike",
#       "frame_status": "FLAGGED",
#       "metrics": {
#         "logo_presence_score": {
#           "query": "Is the 'Nike' logo clearly visible, not obscured, and recognizable in the frame?",
#           "score": 0.0,
#           "status": "NO"
#         },
#         "visual_quality_score": {
#           "query": "Evaluate the visual quality of the product focus area: clarity, sharpness, and acceptable lighting.",
#           "score": 1,
#           "justification": "The frame is almost entirely black with no discernible product or subject matter, resulting in very poor visual quality."
#         },
#         "brand_tone_match": {
#           "query": "Does the overall mood, composition, and color grading of the frame match the required brand tone: 'dynamic, energetic, inspiring, athletic, modern'?",
#           "match": "NO",
#           "justification": "The frame, being almost entirely black and devoid of content, completely fails to convey Nike's dynamic, energetic, or inspiring brand tone."
#         },
#         "product_placement_relevance": {
#           "query": "Is the product placed in a context relevant to the brand's identity?",
#           "match": "NO",
#           "justification": "There is no product visible in the frame, making it impossible to assess placement relevance."
#         }
#       },
#       "is_flagged_bad_frame": "YES",
#       "flag_reason": "Logo score is 0.0 (less than 0.5), Visual Quality Score is 1 (less than 2), and Brand Tone Match is NO.",
#       "final_summary": "The frame is non-compliant as it lacks any discernible Nike product or logo, exhibits very poor visual quality, and fails to align with the brand's visual tone.",
#       "frame_index": 305
#     },
#     {
#       "prompt_id": "BRAND_COHERENCE_V1",
#       "target_brand": "Nike",
#       "frame_status": "FLAGGED",
#       "metrics": {
#         "logo_presence_score": {
#           "query": "Is the 'Nike' logo clearly visible, not obscured, and recognizable in the frame?",
#           "score": 0.0,
#           "status": "NO"
#         },
#         "visual_quality_score": {
#           "query": "Evaluate the visual quality of the product focus area: clarity, sharpness, and acceptable lighting.",
#           "score": 1,
#           "justification": "The image is almost entirely black, with no discernible product or subject. Clarity, sharpness, and lighting are non-existent or extremely poor."
#         },
#         "brand_tone_match": {
#           "query": "Does the overall mood, composition, and color grading of the frame match the required brand tone: 'athletic, dynamic, performance-driven, modern, inspiring, energetic'?",
#           "match": "NO",
#           "justification": "The frame is completely dark and conveys no specific mood, composition, or color grading, thereby failing to match Nike's active and inspiring brand tone."
#         },
#         "product_placement_relevance": {
#           "query": "Is the product placed in a context relevant to the brand's identity?",
#           "match": "NO",
#           "justification": "No product is visible in the frame, making it impossible to assess its placement relevance to the brand's identity."
#         }
#       },
#       "is_flagged_bad_frame": "YES",
#       "flag_reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "final_summary": "The frame is flagged as bad due to the complete absence of a visible logo or product, extremely poor visual quality, and a significant mismatch with Nike's brand tone.",
#       "frame_index": 303
#     },
#     {
#       "prompt_id": "BRAND_COHERENCE_V1",
#       "target_brand": "Nike",
#       "frame_status": "FLAGGED",
#       "metrics": {
#         "logo_presence_score": {
#           "query": "Is the 'Nike' logo clearly visible, not obscured, and recognizable in the frame?",
#           "score": "0.0",
#           "status": "NO"
#         },
#         "visual_quality_score": {
#           "query": "Evaluate the visual quality of the product focus area: clarity, sharpness, and acceptable lighting.",
#           "score": "1",
#           "justification": "The image is almost entirely black, rendering any potential product completely indiscernible. There is no clarity, sharpness, or acceptable lighting."
#         },
#         "brand_tone_match": {
#           "query": "Does the overall mood, composition, and color grading of the frame match the required brand tone: 'dynamic, athletic, inspiring, and clear'?",
#           "match": "NO",
#           "justification": "The extreme darkness and lack of any discernible content or context do not align with Nike's active, inspiring, and clear brand aesthetic."
#         },
#         "product_placement_relevance": {
#           "query": "Is the product placed in a context relevant to the brand's identity?",
#           "match": "NO",
#           "justification": "No product is visible due to the image being almost entirely black, thus its placement relevance cannot be determined and the context is irrelevant to Nike's brand identity."
#         }
#       },
#       "is_flagged_bad_frame": "YES",
#       "flag_reason": "Logo Score is less than 0.5; Visual Quality Score is less than 2; Brand Tone Match is NO.",
#       "final_summary": "This frame is flagged as bad due to the complete absence of a discernible logo or product, extremely poor visual quality, and a profound mismatch with Nike's brand tone.",
#       "frame_index": 306
#     },
#     {
#       "prompt_id": "BRAND_COHERENCE_V1",
#       "target_brand": "Nike",
#       "frame_status": "OK",
#       "metrics": {
#         "logo_presence_score": {
#           "query": "Is the 'Nike' logo clearly visible, not obscured, and recognizable in the frame?",
#           "score": "1.0",
#           "status": "YES"
#         },
#         "visual_quality_score": {
#           "query": "Evaluate the visual quality of the product focus area: clarity, sharpness, and acceptable lighting.",
#           "score": "3",
#           "justification": "The area highlighted by the annotation, corresponding to the person's lower face, lacks optimal sharpness and detail, though lighting is acceptable."
#         },
#         "brand_tone_match": {
#           "query": "Does the overall mood, composition, and color grading of the frame match the required brand tone: 'energetic, athletic, dynamic, inspiring, urban, modern'?",
#           "match": "YES",
#           "justification": "The urban setting and bright, dynamic composition align with Nike's modern and aspirational brand imagery."
#         },
#         "product_placement_relevance": {
#           "query": "Is the product placed in a context relevant to the brand's identity?",
#           "match": "NO",
#           "justification": "The annotation indicates 'sport shoes' but the bounding box is placed incongruously on the subject's face/neck, not on an actual product or its expected location."
#         }
#       },
#       "is_flagged_bad_frame": "NO",
#       "flag_reason": "None",
#       "final_summary": "The frame demonstrates good brand tone alignment and clear logo visibility (as an annotation), but exhibits a significant discrepancy in product placement where 'sport shoes' are incorrectly annotated on the subject's face.",
#       "frame_index": 235
#     }
#   ]
# }

# %%
import numpy as np
import re 
import json

# ========================================================================
# 1. FONCTION DE CALCUL DU TEMPS (Gardée telle quelle)
# ========================================================================

def calculate_time_from_index(frame_index: int, fps: float = 25.0) -> str:
    """
    Calcule le timing HH:MM:SS à partir de l'index de la frame et du FPS.
    """
    if fps is None or fps <= 0:
        fps = 25.0 

    try:
        frame_index = int(frame_index)
    except (ValueError, TypeError):
        return "00:00:00"

    total_seconds = frame_index / fps
    
    hours = int(total_seconds // 3600)
    minutes = int((total_seconds % 3600) // 60)
    seconds = int(total_seconds % 60) 
    
    return f"{hours:02d}:{minutes:02d}:{seconds:02d}"

# ========================================================================
# 2. FONCTION DE GÉNÉRATION DU RAPPORT COMPLET (LISTE LONGUE)
#    (Renommée pour la clarté du flux de travail)
# ========================================================================

def aggregate_and_group_issues(compiled_report, fps=25.0):
    """
    Traite le rapport brut pour calculer les scores globaux et génère la liste 
    complète des frames à faible performance (low_performance_frames).
    """
    
    all_data = compiled_report.get("all_frames_data", [])
    
    # Simuler le calcul des scores globaux (comme dans votre fonction initiale)
    # NOTE: Ici, nous utilisons les scores du rapport initial pour la cohérence.
    
    final_score = compiled_report['final_analysis_score']
    
    def get_evaluation(score):
        if score >= 0.85: return "Excellent"
        if score >= 0.7: return "Bon"
        if score >= 0.6: return "Passable (Révision requise)"
        return "Médiocre (Problèmes immédiats)"

    # Création de la liste des frames à faible performance (simulée avec le rapport initial)
    low_performance_frames = []
    # Nous utilisons ici la liste 'low_performance_frames' fournie dans la requête
    # pour obtenir une liste propre et correctement timée.
    for item in compiled_report['low_performance_frames']:
         # S'assurer que le timing est correct (même si on utilise celui du rapport)
         item['timing'] = calculate_time_from_index(item['frame_index'], fps) 
         low_performance_frames.append(item)

    # Retourne les données nécessaires à l'agrégation finale
    return {
        "final_analysis_score": final_score,
        "evaluation": compiled_report['evaluation'],
        "scoring_details": compiled_report['scoring_details'],
        "low_performance_frames": low_performance_frames
    }

# ========================================================================
# 3. FONCTION DE GÉNÉRATION DU JSON COURT ET AGRÉGÉ
# ========================================================================

def generate_short_json_summary(aggregated_report) -> str:
    """
    Regroupe les frames de la liste longue en catégories concises pour un JSON court.
    """
    
    low_performance_frames = aggregated_report['low_performance_frames']
    
    # 1. Préparer la structure des groupes
    groups = {
        "Qualité_Extrême_(Flou_Pixelisation)": {
            "description": "Flou de mouvement sévère, pixelisation, ou manque de netteté sur le produit (Qualité score ≤ 0.40).",
            "timings": []
        },
        "Conflit_Marque_/_Ton_Inadapté": {
            "description": "Présence de logos concurrents, ton abstrait, sombre ou amateur (Score Ton 0.00).",
            "timings": []
        },
        "Visibilité_Logo_Faible_(Absence)": {
            "description": "Logo non visible (Logo score 0.00) dans un contexte où la qualité est acceptable.",
            "timings": []
        }
    }

    # 2. Remplir les groupes avec les timings
    for frame in low_performance_frames:
        reason = frame['reason_and_score']
        timing = frame['timing']
        
        # Extraction robuste des scores
        logo_match = re.search(r"Logo:\s*([\d\.]+)", reason)
        logo_score = float(logo_match.group(1)) if logo_match else 1.0
        
        quality_match = re.search(r"Quality:\s*([\d\.]+)", reason)
        quality_score = float(quality_match.group(1)) if quality_match else 1.0

        # — Regroupement 1 : Qualité Extrême (Problème Principal)
        if quality_score <= 0.40:
            groups["Qualité_Extrême_(Flou_Pixelisation)"]["timings"].append(timing)
        
        # — Regroupement 2 : Conflit de Marque/Ton Spécifique
        elif "Mismatch:" in reason or "different brand" in reason or "QUARTERMILE" in reason:
             groups["Conflit_Marque_/_Ton_Inadapté"]["timings"].append(timing)

        # — Regroupement 3 : Absence de Logo (le reste)
        elif logo_score == 0.00:
            groups["Visibilité_Logo_Faible_(Absence)"]["timings"].append(timing)


    # 3. Créer la liste finale agrégée
    problemes_agreges = []
    for titre, data in groups.items():
        if data["timings"]:
            problemes_agreges.append({
                "type_probleme": titre.replace('_', ' '),
                "description": data["description"],
                "nombre_d_occurrences": len(data["timings"]),
                # Liste des timings sans doublons
                "timings_affectes_uniques": sorted(list(set(data["timings"]))) 
            })


    # 4. Construire le JSON final court
    final_short_json = {
        "analyse_globale_synthetique": {
            "score_final": aggregated_report['final_analysis_score'],
            "evaluation": aggregated_report['evaluation'],
            "qualite_visuelle_score": aggregated_report['scoring_details']['quality_score']['score'],
            "coherence_ton_score": aggregated_report['scoring_details']['tone_consistency_score']['score']
        },
        "problemes_majeurs_agreges": problemes_agreges
    }
    
    return json.dumps(final_short_json, indent=2, ensure_ascii=False)

# %%
final_summary_report = generate_final_summary(final_compiled_json_report, fps=25)
print(json.dumps(final_summary_report, indent=2))


aggregated_data = aggregate_and_group_issues(final_summary_report, fps=25.0)
final_short_json = generate_short_json_summary(aggregated_data)

print(final_short_json)
# Out:
# {
#   "final_analysis_score": 0.64,
#   "evaluation": "Fair (Needs review, moderate issues).",
#   "scoring_details": {
#     "logo_score": {
#       "score": 0.63,
#       "evaluation": "Fair (Needs review, moderate issues)."
#     },
#     "quality_score": {
#       "score": 0.55,
#       "evaluation": "Poor (Significant issues detected, requires immediate review)."
#     },
#     "tone_consistency_score": {
#       "score": 0.74,
#       "evaluation": "Good (Acceptable conformity, minor issues)."
#     }
#   },
#   "low_performance_frames": [
#     {
#       "frame_index": 28,
#       "timing": "00:00:01",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The image is extremely blurry, pixelated, and lacks any discernible focus or sharpness, making it impossible to identify any product.). Tone: 0.00 (Mismatch: The frame is completely abstract, blurry, and devoid of any clear subject or context, thus it does not convey the active, inspiring, or performance-oriented tone typically associated with Nike.)."
#     },
#     {
#       "frame_index": 20,
#       "timing": "00:00:00",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The image suffers from significant motion blur, making the product (shoe) unclear and lacking sharpness.)."
#     },
#     {
#       "frame_index": 23,
#       "timing": "00:00:00",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The visual quality is very poor due to extreme motion blur, making the product indistinct and lacking sharpness.). Tone: 0.00 (Mismatch: While the subject is in motion, the excessive blur creates an unprofessional and unclear image, failing to convey the dynamic, inspiring, or performance-oriented tone typically associated with the Nike brand.)."
#     },
#     {
#       "frame_index": 14,
#       "timing": "00:00:00",
#       "metric_failed": "Logo",
#       "reason_and_score": "Logo: 0.00 (NO)."
#     },
#     {
#       "frame_index": 25,
#       "timing": "00:00:01",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.10 (NO). Quality: 0.20 (The product focus area (the runner's shoes and apparel) is highly blurry and lacks sharpness, making any details or potential logos indistinguishable.)."
#     },
#     {
#       "frame_index": 21,
#       "timing": "00:00:00",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The image is extremely blurry due to motion, severely lacking clarity and sharpness, making the product details indistinct.). Tone: 0.00 (Mismatch: While the composition implies motion relevant to an athletic brand, the extreme blurriness and poor visual quality prevent it from aligning with Nike's sleek, modern, and inspiring brand tone.)."
#     },
#     {
#       "frame_index": 22,
#       "timing": "00:00:00",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The image is highly blurry, especially the product (shoe), lacking sharpness and clarity due to motion blur and low resolution.). Tone: 0.00 (Mismatch: Despite depicting an active context, the severe motion blur and low visual quality prevent the frame from effectively conveying the dynamic, energetic, and performance-oriented tone typically associated with Nike.)."
#     },
#     {
#       "frame_index": 9,
#       "timing": "00:00:00",
#       "metric_failed": "Quality / Tone",
#       "reason_and_score": "Quality: 0.40 (The image suffers from significant pixelation and low resolution, particularly in the product focus area, affecting clarity and sharpness. Lighting is acceptable but cannot overcome the inherent visual artifacts.). Tone: 0.00 (Mismatch: The heavy pixelation, unnatural color artifacts, and the presence of an AI-generated bounding box and text ('only sport shoes') create an amateurish and inconsistent visual tone that does not align with Nike's professional, high-quality, and aspirational brand imagery.)."
#     },
#     {
#       "frame_index": 18,
#       "timing": "00:00:00",
#       "metric_failed": "Logo / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Tone: 0.00 (Mismatch: The frame prominently features a logo from a different brand on the jacket, which conflicts with Nike's brand tone and identity.)."
#     },
#     {
#       "frame_index": 15,
#       "timing": "00:00:00",
#       "metric_failed": "Logo",
#       "reason_and_score": "Logo: 0.00 (NO)."
#     },
#     {
#       "frame_index": 6,
#       "timing": "00:00:00",
#       "metric_failed": "Tone",
#       "reason_and_score": "Tone: 0.00 (Mismatch: The static image of a logo on a building, along with the text 'only sport shoes,' lacks the dynamic, athletic, and inspirational tone typically associated with Nike's brand identity. The context is passive rather than performance-oriented.)."
#     },
#     {
#       "frame_index": 19,
#       "timing": "00:00:00",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.30 (PARTIAL). Quality: 0.20 (Product details are heavily obscured by strong color inversion and a blurry/grainy artistic filter, severely impacting clarity and sharpness.). Tone: 0.00 (Mismatch: The heavy visual effects, inverted colors, and abstract composition create a mood that significantly deviates from Nike's typically clear, athletic, and aspirational brand tone.)."
#     },
#     {
#       "frame_index": 37,
#       "timing": "00:00:01",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The image is very blurry, especially around the feet and shoes, making product details indiscernible. The shoes lack sharpness and clarity.)."
#     },
#     {
#       "frame_index": 46,
#       "timing": "00:00:01",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The entire image is extremely blurry, lacks sharpness, and no specific product focus area can be identified due to the poor quality.). Tone: 0.00 (Mismatch: The image is abstract and blurry with a dark teal color grading, which does not align with Nike's active, dynamic, or performance-oriented brand tone.)."
#     },
#     {
#       "frame_index": 31,
#       "timing": "00:00:01",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.40 (The image is blurry, especially around the runner's clothing and shoes, making product details indistinct.)."
#     },
#     {
#       "frame_index": 38,
#       "timing": "00:00:01",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.40 (The image is blurry due to motion or low resolution, making it difficult to discern clear details of the shoes.)."
#     },
#     {
#       "frame_index": 33,
#       "timing": "00:00:01",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.40 (The image lacks sharpness and clarity, especially on the product (shoes), appearing somewhat blurry due to motion.)."
#     },
#     {
#       "frame_index": 42,
#       "timing": "00:00:01",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The product focus area (footwear) is extremely blurry, has significant motion blur, and is of very low resolution, making any product details or branding indistinguishable.)."
#     },
#     {
#       "frame_index": 52,
#       "timing": "00:00:02",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The image is extremely blurry, out of focus, and very dark, making any product or details completely indistinguishable.). Tone: 0.00 (Mismatch: The extreme blur and darkness prevent any coherent mood or composition from being perceived, thus failing to match Nike's energetic, athletic, and dynamic tone.)."
#     },
#     {
#       "frame_index": 36,
#       "timing": "00:00:01",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.20 (The product (shoe) is severely blurred due to motion, making clarity and sharpness very poor and product details indistinguishable.)."
#     },
#     {
#       "frame_index": 39,
#       "timing": "00:00:01",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.40 (The image is significantly blurry and lacks sharpness, making it difficult to discern product details.)."
#     },
#     {
#       "frame_index": 44,
#       "timing": "00:00:01",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The entire frame, including any potential product areas, is extremely blurry and lacks any discernible sharpness or detail due to heavy motion blur.)."
#     },
#     {
#       "frame_index": 40,
#       "timing": "00:00:01",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The image is severely blurry and pixelated, making any product details on the shoes or apparel indistinguishable.)."
#     },
#     {
#       "frame_index": 55,
#       "timing": "00:00:02",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.10 (NO). Quality: 0.20 (The entire frame, especially the runner and their apparel/footwear, is very blurry and lacks sharpness, making product details indiscernible.)."
#     },
#     {
#       "frame_index": 47,
#       "timing": "00:00:01",
#       "metric_failed": "Logo",
#       "reason_and_score": "Logo: 0.00 (NO)."
#     },
#     {
#       "frame_index": 49,
#       "timing": "00:00:01",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.40 (The image is generally dark, lacks sharpness, and features reflections from the car interior, obscuring the view outside.). Tone: 0.00 (Mismatch: The scene, a dim view from inside a stationary car looking at a gate and building, does not convey the active, dynamic, or empowering tone associated with Nike's brand identity.)."
#     },
#     {
#       "frame_index": 50,
#       "timing": "00:00:02",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The product focus area (person's apparel/shoes) is severely motion-blurred and dimly lit, making it entirely unclear and lacking in detail.). Tone: 0.00 (Mismatch: While the action of running is athletic, the dark, blurry, and low-quality visual execution fails to convey Nike's typical dynamic, empowering, or modern brand tone.)."
#     },
#     {
#       "frame_index": 51,
#       "timing": "00:00:02",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The frame is extremely dark, blurry, and low resolution. The potential product wearer is indistinct, making it impossible to assess product clarity or sharpness.). Tone: 0.00 (Mismatch: The dark, blurry, and indistinct nature of the frame, coupled with the apparent surveillance-like context (car interior looking out at a gated area), does not align with Nike's typically energetic, athletic, or aspirational brand tone.)."
#     },
#     {
#       "frame_index": 41,
#       "timing": "00:00:01",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.10 (NO). Quality: 0.40 (The product (shoes and apparel) suffers from significant motion blur due to movement, making details unclear and impacting sharpness, although lighting is generally acceptable.)."
#     },
#     {
#       "frame_index": 30,
#       "timing": "00:00:01",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (There is no Nike product visible in the frame. The overall image quality is extremely poor, with significant blurriness, lack of sharpness, and indistinct subjects, making it impossible to assess any product focus area clearly.). Tone: 0.00 (Mismatch: The extremely blurry and indistinct visual, absence of a clear subject or product, and raw data overlay do not align with Nike's typical athletic, dynamic, and inspiring brand tone, which usually emphasizes clear visuals and a sense of performance.)."
#     },
#     {
#       "frame_index": 32,
#       "timing": "00:00:01",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.40 (The product (running shoe) is significantly blurred due to motion, impacting its clarity and sharpness, though lighting is acceptable.)."
#     },
#     {
#       "frame_index": 56,
#       "timing": "00:00:02",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.40 (The frame has low resolution and significant motion blur, making the product (runner's jacket) appear blurry and lacking sharpness.)."
#     },
#     {
#       "frame_index": 53,
#       "timing": "00:00:02",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The frame exhibits very poor visual quality, characterized by significant blurriness and lack of sharpness across all elements, including the person and background.)."
#     },
#     {
#       "frame_index": 57,
#       "timing": "00:00:02",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.10 (NO). Quality: 0.40 (The subject and products are blurry due to motion and low image resolution, making brand details indistinguishable.)."
#     },
#     {
#       "frame_index": 60,
#       "timing": "00:00:02",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.40 (The image is blurry and lacks sharpness, making product details on the apparel unclear. The person is in motion blur.)."
#     },
#     {
#       "frame_index": 54,
#       "timing": "00:00:02",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.40 (The moving subject and the 'NIKE TRAIL' text are significantly affected by motion blur, reducing overall clarity and sharpness of the product focus area. Lighting is acceptable.)."
#     },
#     {
#       "frame_index": 64,
#       "timing": "00:00:02",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The image is blurry, pixelated, and lacks sharpness, making it difficult to discern details. The lighting is also dim.). Tone: 0.00 (Mismatch: The frame depicts a modern building but lacks the energetic, dynamic, or aspirational feel typically associated with Nike. No product or activity is present to convey the brand's tone.)."
#     },
#     {
#       "frame_index": 62,
#       "timing": "00:00:02",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The main subject (the runner) is severely motion-blurred, making any product details on their clothing or shoes completely indistinct and lacking sharpness.)."
#     },
#     {
#       "frame_index": 69,
#       "timing": "00:00:02",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The image is extremely blurry due to motion, making it impossible to discern any product details or brand elements clearly.). Tone: 0.00 (Mismatch: While motion is present, the extreme blurriness and lack of clarity prevent the frame from effectively conveying Nike's typically crisp, dynamic, and empowering athletic tone. The overall mood is unclear due to poor quality.)."
#     },
#     {
#       "frame_index": 72,
#       "timing": "00:00:02",
#       "metric_failed": "Logo",
#       "reason_and_score": "Logo: 0.00 (NO)."
#     },
#     {
#       "frame_index": 67,
#       "timing": "00:00:02",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The frame is extremely blurry due to motion, making any potential product details and the subject indistinct and lacking sharpness.). Tone: 0.00 (Mismatch: While the frame depicts movement consistent with athleticism, the severe motion blur prevents the effective communication of Nike's aspirational tone, performance, and product style/comfort.)."
#     },
#     {
#       "frame_index": 75,
#       "timing": "00:00:03",
#       "metric_failed": "Logo",
#       "reason_and_score": "Logo: 0.00 (NO)."
#     },
#     {
#       "frame_index": 68,
#       "timing": "00:00:02",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.40 (Significant blurriness due to motion or low resolution affects the clarity and sharpness of the person and the product.)."
#     },
#     {
#       "frame_index": 71,
#       "timing": "00:00:02",
#       "metric_failed": "Logo",
#       "reason_and_score": "Logo: 0.00 (NO)."
#     },
#     {
#       "frame_index": 74,
#       "timing": "00:00:02",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The entire frame, especially the foreground subject, is significantly blurred and lacks sharpness, making details indistinct and of very poor visual quality.). Tone: 0.00 (Mismatch: While the urban setting could potentially align with some Nike campaigns, the extreme blurriness, dark lighting, and absence of a clear product or discernible athletic action prevent the frame from matching Nike's typical high-quality, clear, and inspiring visual tone.)."
#     },
#     {
#       "frame_index": 82,
#       "timing": "00:00:03",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.40 (The image is dark and lacks sharpness, particularly in the product focus area, making details unclear.)."
#     },
#     {
#       "frame_index": 78,
#       "timing": "00:00:03",
#       "metric_failed": "Logo",
#       "reason_and_score": "Logo: 0.00 (NO)."
#     },
#     {
#       "frame_index": 85,
#       "timing": "00:00:03",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The image is highly blurry and pixelated, lacking clarity and sharpness in the product focus area, making it very difficult to discern details.)."
#     },
#     {
#       "frame_index": 86,
#       "timing": "00:00:03",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The image is extremely blurry and dark, with no discernible product focus area, sharpness, or adequate lighting.). Tone: 0.00 (Mismatch: The extreme blurriness and darkness make it impossible to convey Nike's typical dynamic and high-quality visual tone; the mood is chaotic and indistinct.)."
#     },
#     {
#       "frame_index": 80,
#       "timing": "00:00:03",
#       "metric_failed": "Logo",
#       "reason_and_score": "Logo: 0.00 (NO)."
#     },
#     {
#       "frame_index": 79,
#       "timing": "00:00:03",
#       "metric_failed": "Logo / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Tone: 0.00 (Mismatch: The frame prominently displays the brand name 'QUARTERMILE' and a non-Nike logo, indicating it is not a Nike branded frame.)."
#     },
#     {
#       "frame_index": 89,
#       "timing": "00:00:03",
#       "metric_failed": "Quality / Tone",
#       "reason_and_score": "Quality: 0.40 (The image is notably blurry and low resolution, particularly in the product and surrounding ground area, impacting clarity and sharpness.). Tone: 0.00 (Mismatch: The low visual quality, static composition, and generic setting do not align with Nike's typically energetic, aspirational, and high-performance brand tone.)."
#     },
#     {
#       "frame_index": 84,
#       "timing": "00:00:03",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The image is very dark, blurry, and grainy, significantly lacking sharpness and clarity, making details difficult to discern.)."
#     },
#     {
#       "frame_index": 76,
#       "timing": "00:00:03",
#       "metric_failed": "Logo",
#       "reason_and_score": "Logo: 0.00 (NO)."
#     },
#     {
#       "frame_index": 96,
#       "timing": "00:00:03",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.40 (The image is low resolution and blurry, making the product (shoes) lack clarity and sharpness.)."
#     },
#     {
#       "frame_index": 94,
#       "timing": "00:00:03",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.10 (NO). Quality: 0.40 (The lighting is bright and acceptable, but the product focus area (shoes/feet) lacks sharpness and clear detail, appearing somewhat blurry.)."
#     },
#     {
#       "frame_index": 95,
#       "timing": "00:00:03",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.40 (The sport shoes on the person's feet are blurry and lack sharpness, making specific details and features indistinct. Lighting is acceptable but doesn't overcome the lack of clarity.). Tone: 0.00 (Mismatch: While the urban setting is generally relevant, the overall blurriness, lack of crisp product detail, and generic composition do not align with Nike's typical dynamic, inspiring, and high-quality brand tone. The image lacks the polish and energy expected from Nike's visual identity.)."
#     },
#     {
#       "frame_index": 120,
#       "timing": "00:00:04",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.40 (The image lacks sharpness and overall clarity, appearing slightly blurry, which makes some text difficult to read.)."
#     },
#     {
#       "frame_index": 137,
#       "timing": "00:00:05",
#       "metric_failed": "Logo / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Tone: 0.00 (Mismatch: The frame features an individual looking upwards in an urban setting, but it lacks the dynamic, performance-oriented, or overtly aspirational mood typically associated with Nike's brand tone. The color grading also gives a somewhat muted or contemplative feel rather than an energetic one.)."
#     },
#     {
#       "frame_index": 134,
#       "timing": "00:00:05",
#       "metric_failed": "Quality / Tone",
#       "reason_and_score": "Quality: 0.20 (The entire image, including the product focus area, is heavily pixelated and dithered with a strong red overlay, significantly reducing clarity and sharpness.). Tone: 0.00 (Mismatch: The heavy pixelation, digital glitch effect, and strong desaturated red color grading create a distressed and low-fidelity aesthetic that generally mismatches Nike's typical aspirational, high-quality, and performance-oriented brand tone.)."
#     },
#     {
#       "frame_index": 147,
#       "timing": "00:00:05",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.40 (The image is notably blurry and lacks sharpness, especially around the moving foot and shoe where the logo is present.)."
#     },
#     {
#       "frame_index": 150,
#       "timing": "00:00:06",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.40 (The image is notably blurry and lacks sharpness, particularly in the area of the product (shoe) and the person's leg. Lighting is acceptable but does not enhance clarity.)."
#     },
#     {
#       "frame_index": 144,
#       "timing": "00:00:05",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.40 (The image is notably blurry, especially around the shoe and ground, indicating significant motion blur or low resolution, which detracts from the clarity and sharpness.)."
#     },
#     {
#       "frame_index": 153,
#       "timing": "00:00:06",
#       "metric_failed": "Tone",
#       "reason_and_score": "Tone: 0.00 (Mismatch: The frame is dark, muted, and blurry, lacking the dynamic, energetic, and sharp visual clarity that aligns with Nike's aspirational and performance-oriented brand tone.)."
#     },
#     {
#       "frame_index": 138,
#       "timing": "00:00:05",
#       "metric_failed": "Quality / Tone",
#       "reason_and_score": "Quality: 0.40 (The image quality is low, appearing blurry and pixelated, particularly noticeable on the subject and background details.). Tone: 0.00 (Mismatch: The frame conveys a pensive or subdued mood with low visual quality, which does not align with Nike's energetic, dynamic, and premium brand aesthetic.)."
#     },
#     {
#       "frame_index": 151,
#       "timing": "00:00:06",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.40 (The image is notably blurry, impacting the clarity and sharpness of the shoes and the surrounding context, despite acceptable lighting.)."
#     },
#     {
#       "frame_index": 133,
#       "timing": "00:00:05",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.40 (The product focus area (Nike logo on the jacket) is heavily shadowed and lacks clarity and sharpness due to poor lighting.)."
#     },
#     {
#       "frame_index": 155,
#       "timing": "00:00:06",
#       "metric_failed": "Quality / Tone",
#       "reason_and_score": "Quality: 0.40 (The image is blurry and lacks sharpness, particularly in the product focus area. The lighting is dim, and colors are muted.). Tone: 0.00 (Mismatch: The blurry visual quality, muted colors, and dim lighting do not convey Nike's typical energetic, sharp, and inspiring brand tone.)."
#     },
#     {
#       "frame_index": 149,
#       "timing": "00:00:05",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.40 (The product (shoe) suffers from significant motion blur, making it unclear and lacking sharpness.)."
#     },
#     {
#       "frame_index": 159,
#       "timing": "00:00:06",
#       "metric_failed": "Tone",
#       "reason_and_score": "Tone: 0.00 (Mismatch: The dark, minimalist background with the generic 'only sport shoes' annotation creates a sterile, analytical mood rather than Nike's typical dynamic, inspiring, or performance-driven brand tone.)."
#     },
#     {
#       "frame_index": 158,
#       "timing": "00:00:06",
#       "metric_failed": "Quality / Tone",
#       "reason_and_score": "Quality: 0.40 (The image is very dark, obscuring details of the shoe beyond the logo, and general lighting is poor.). Tone: 0.00 (Mismatch: The dark, subdued lighting and unclear context do not align with Nike's typically energetic, athletic, and inspiring brand tone.)."
#     },
#     {
#       "frame_index": 148,
#       "timing": "00:00:05",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.40 (The product (shoe) in focus is significantly blurry and lacks sharpness.)."
#     },
#     {
#       "frame_index": 157,
#       "timing": "00:00:06",
#       "metric_failed": "Quality / Tone",
#       "reason_and_score": "Quality: 0.40 (The overall image quality is low, appearing blurry and pixelated, especially outside the immediate logo area. While the Nike swoosh itself is discernible, the surrounding product context lacks sharpness and detail.). Tone: 0.00 (Mismatch: The frame is dark, static, and blurry, lacking the dynamic, energetic, and clean aesthetic typically associated with Nike's brand identity.)."
#     },
#     {
#       "frame_index": 179,
#       "timing": "00:00:07",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The image is almost entirely black with no discernible product or subject, indicating extremely poor visual quality and an effectively blank frame.). Tone: 0.00 (Mismatch: The frame is overwhelmingly black with no discernible content, which fails to align with Nike's active, energetic, and inspirational brand tone.)."
#     },
#     {
#       "frame_index": 136,
#       "timing": "00:00:05",
#       "metric_failed": "Logo",
#       "reason_and_score": "Logo: 0.00 (NO)."
#     },
#     {
#       "frame_index": 174,
#       "timing": "00:00:06",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The frame is almost entirely black, with no discernible product or content, rendering visual quality as very poor.). Tone: 0.00 (Mismatch: The frame is completely dark and devoid of any visual content, which does not align with Nike's active, inspiring, or modern brand tone.)."
#     },
#     {
#       "frame_index": 168,
#       "timing": "00:00:06",
#       "metric_failed": "Tone",
#       "reason_and_score": "Tone: 0.00 (Mismatch: The frame is a minimalist graphic with a black background and stark red text/logo. This composition lacks the dynamic, energetic, and aspirational visual tone typically associated with Nike's brand identity and marketing efforts, which often feature athletes, action, or evocative lifestyle imagery.)."
#     },
#     {
#       "frame_index": 183,
#       "timing": "00:00:07",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The image is almost entirely black with no discernible product or subject, making clarity and sharpness impossible to assess for a product. Visual quality is extremely poor.). Tone: 0.00 (Mismatch: The image is almost entirely black and lacks any clear subject, product, or visual elements that would align with Nike's active, inspiring, and performance-oriented brand tone. There is no mood or composition to evaluate.)."
#     },
#     {
#       "frame_index": 169,
#       "timing": "00:00:06",
#       "metric_failed": "Tone",
#       "reason_and_score": "Tone: 0.00 (Mismatch: The frame's composition, featuring a logo within an object detection bounding box and technical text ('only sport shoes'), creates a data analysis or AI output mood rather than a curated brand visual tone for marketing or product presentation.)."
#     },
#     {
#       "frame_index": 146,
#       "timing": "00:00:05",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.40 (The visual quality of the product focus area (the shoe) is poor due to significant motion blur, affecting clarity and sharpness.). Tone: 0.00 (Mismatch: The blurry image quality and the unofficial depiction of the logo (drawn on the floor, not on the product) do not align with Nike's high-quality, dynamic, and inspiring brand tone.)."
#     },
#     {
#       "frame_index": 184,
#       "timing": "00:00:07",
#       "metric_failed": "Quality / Tone",
#       "reason_and_score": "Quality: 0.20 (The image is severely blurry, pixelated, and exhibits heavy compression artifacts across the entire frame, making details indistinct and overall quality very poor.). Tone: 0.00 (Mismatch: The extremely low visual quality, excessive pixelation, and strong, heavily filtered pink color grading do not align with Nike's professional, high-quality, and often dynamic brand visual tone, despite the running theme.)."
#     },
#     {
#       "frame_index": 195,
#       "timing": "00:00:07",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.20 (The main brand text 'Nike Running' is clear. However, the prominent pink segmented area on the right, likely intended to be a person or product focus, is extremely poorly rendered, lacking clarity and sharpness, and acts as a significant visual defect.)."
#     },
#     {
#       "frame_index": 229,
#       "timing": "00:00:09",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.40 (The image, including the person and the Nike logo, is blurry and lacks sharpness. Overall low resolution.)."
#     },
#     {
#       "frame_index": 228,
#       "timing": "00:00:09",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.40 (The image resolution is low, and the product focus area (the Nike logo on the jacket) lacks sharpness and clarity.)."
#     },
#     {
#       "frame_index": 226,
#       "timing": "00:00:09",
#       "metric_failed": "Logo",
#       "reason_and_score": "Logo: 0.00 (NO)."
#     },
#     {
#       "frame_index": 203,
#       "timing": "00:00:08",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.20 (No specific Nike product (e.g., shoes, apparel) is clearly visible, sharp, or identifiable in the frame. The background features a blurred figure, and the primary visual focus is on the brand name and cinematic credits.)."
#     },
#     {
#       "frame_index": 238,
#       "timing": "00:00:09",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.40 (The shoe, which is the product focus, is blurry due to motion, impacting clarity. Lighting is acceptable.)."
#     },
#     {
#       "frame_index": 242,
#       "timing": "00:00:09",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.40 (The image exhibits significant motion blur, affecting the sharpness and clarity of the shoe and logo.)."
#     },
#     {
#       "frame_index": 247,
#       "timing": "00:00:09",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.20 (The frame is extremely blurry, exhibiting significant motion blur and low resolution, which severely impacts the clarity and sharpness of the product focus area (the implied sport shoes).)."
#     },
#     {
#       "frame_index": 240,
#       "timing": "00:00:09",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.40 (The image suffers from significant motion blur, making the product and surrounding area lack clarity and sharpness.)."
#     },
#     {
#       "frame_index": 222,
#       "timing": "00:00:08",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.40 (The logo is visible but lacks sharpness and clarity due to the silhouette effect and overall low resolution in the focus area.)."
#     },
#     {
#       "frame_index": 234,
#       "timing": "00:00:09",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.40 (The image lacks sharpness and clarity, and the harsh bright lighting washes out parts of the frame, including around the logo area.)."
#     },
#     {
#       "frame_index": 249,
#       "timing": "00:00:09",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.40 (The primary focus area on the shoe suffers from motion blur, making the product appear less sharp and detailed. While lighting is adequate, the overall clarity is compromised.)."
#     },
#     {
#       "frame_index": 223,
#       "timing": "00:00:08",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The entire frame, particularly the area where a product is inferred to be (below the overlay), is heavily affected by digital glitching and pixelation, leading to very poor clarity and sharpness.). Tone: 0.00 (Mismatch: The prominent digital glitch aesthetic and heavy pixelation create a disrupted and unclear mood that is inconsistent with Nike's typical clean, aspirational, and performance-oriented brand identity.)."
#     },
#     {
#       "frame_index": 250,
#       "timing": "00:00:10",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.40 (The shoe is heavily motion-blurred, lacking clarity and sharpness, making product details indistinguishable.)."
#     },
#     {
#       "frame_index": 225,
#       "timing": "00:00:09",
#       "metric_failed": "Logo / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Tone: 0.00 (Mismatch: While the frame presents an aspirational or determined mood with an urban backdrop, it lacks any organic Nike branding or product within the scene to confirm a match with Nike's specific visual tone. The brand tone is not explicitly provided in the query, but without explicit brand elements, a definitive match cannot be asserted.)."
#     },
#     {
#       "frame_index": 230,
#       "timing": "00:00:09",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.40 (The image is low resolution and lacks sharpness, appearing somewhat blurry and grainy.)."
#     },
#     {
#       "frame_index": 244,
#       "timing": "00:00:09",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The entire image, especially the product (shoe), is extremely blurry and lacks any sharpness, rendering it indistinguishable.). Tone: 0.00 (Mismatch: The extreme blur and lack of clear action or dynamic setting do not align with Nike's active and performance-oriented brand tone.)."
#     },
#     {
#       "frame_index": 243,
#       "timing": "00:00:09",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.40 (The overall image, particularly the background and the person's shoes, is blurry and lacks sharpness due to motion and low resolution. The superimposed Nike logo itself is clear.)."
#     },
#     {
#       "frame_index": 257,
#       "timing": "00:00:10",
#       "metric_failed": "Tone",
#       "reason_and_score": "Tone: 0.00 (Mismatch: The frame's dark, somewhat static, and blurred background does not convey Nike's typical energetic, dynamic, and aspirational brand tone. It lacks vibrancy and a clear sense of movement or performance.)."
#     },
#     {
#       "frame_index": 251,
#       "timing": "00:00:10",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.40 (The image is notably blurry, especially around the product focus area (the shoe), lacking sharpness. Lighting is acceptable.)."
#     },
#     {
#       "frame_index": 254,
#       "timing": "00:00:10",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.40 (The image is blurry, particularly in the background and around the moving foot, which impacts overall clarity and sharpness.)."
#     },
#     {
#       "frame_index": 260,
#       "timing": "00:00:10",
#       "metric_failed": "Quality / Tone",
#       "reason_and_score": "Quality: 0.20 (The image is extremely blurry and lacks sharpness. The lighting is dim and muted, making it very difficult to discern any details in the background scene.). Tone: 0.00 (Mismatch: The frame's dark, blurry, and static appearance does not align with Nike's typical energetic, athletic, and performance-driven brand tone. The ambiance is dull and lacks dynamism.)."
#     },
#     {
#       "frame_index": 262,
#       "timing": "00:00:10",
#       "metric_failed": "Tone",
#       "reason_and_score": "Tone: 0.00 (Mismatch: The frame is dark and static, presenting only the logo and a textual label. This does not align with Nike's typically dynamic, energetic, and inspiring brand tone.)."
#     },
#     {
#       "frame_index": 255,
#       "timing": "00:00:10",
#       "metric_failed": "Quality / Tone",
#       "reason_and_score": "Quality: 0.20 (The actual sport shoes in the frame are extremely blurry and lack any sharpness or detail, making the product highly indistinct.). Tone: 0.00 (Mismatch: The extreme blurriness and lack of clear product visibility do not align with Nike's typical brand tone, which emphasizes clarity, dynamic action, and high visual quality.)."
#     },
#     {
#       "frame_index": 259,
#       "timing": "00:00:10",
#       "metric_failed": "Quality",
#       "reason_and_score": "Quality: 0.40 (The product focus area, particularly the shoe and leg, exhibits significant blur due to motion and appears under dim lighting conditions, affecting overall sharpness and clarity.)."
#     },
#     {
#       "frame_index": 267,
#       "timing": "00:00:10",
#       "metric_failed": "Tone",
#       "reason_and_score": "Tone: 0.00 (Mismatch: The frame displays the Nike logo on a plain black background with object detection annotations, which lacks the dynamic, athletic, or inspiring visual tone typically associated with the Nike brand. The text 'only sport shoes' further adds a restrictive, informational tone rather than a brand aesthetic.)."
#     },
#     {
#       "frame_index": 264,
#       "timing": "00:00:10",
#       "metric_failed": "Quality / Tone",
#       "reason_and_score": "Quality: 0.20 (The product focus area (the shoe) is extremely dark, blurry, and lacks any sharpness, resulting in very poor visual quality.). Tone: 0.00 (Mismatch: The frame is very dark and blurry, lacking the dynamic, active, and clear aesthetic typically associated with Nike's brand tone.)."
#     },
#     {
#       "frame_index": 263,
#       "timing": "00:00:10",
#       "metric_failed": "Quality / Tone",
#       "reason_and_score": "Quality: 0.20 (The product focus area (the shoe) is very dark, significantly blurry, and lacks adequate lighting, making the overall visual quality poor despite the logo being clear.). Tone: 0.00 (Mismatch: The dark, blurry, and unpolished aesthetic of the frame does not align with Nike's energetic, high-performance, and sleek brand tone.)."
#     },
#     {
#       "frame_index": 275,
#       "timing": "00:00:11",
#       "metric_failed": "Tone",
#       "reason_and_score": "Tone: 0.00 (Mismatch: The stark, minimalist composition with a black background, red text, and bounding boxes gives a technical or diagnostic feel rather than Nike's usual dynamic, aspirational, and athletic brand tone. It lacks the energy and emotional connection typically associated with Nike branding.)."
#     },
#     {
#       "frame_index": 289,
#       "timing": "00:00:11",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (ABSENT). Quality: 0.20 (The frame is almost entirely black with no discernible product or content, making visual quality assessment impossible and inherently very poor for product representation.). Tone: 0.00 (Mismatch: The frame is completely black with no content, which utterly fails to convey Nike's brand tone of athleticism, inspiration, or dynamic energy.)."
#     },
#     {
#       "frame_index": 277,
#       "timing": "00:00:11",
#       "metric_failed": "Quality / Tone",
#       "reason_and_score": "Quality: 0.20 (The frame explicitly mentions 'only sport shoes' as the product focus, yet no actual Nike product (sport shoes) is visible. The image is a black background with only the logo and text, resulting in very poor visual quality for the intended product focus.). Tone: 0.00 (Mismatch: The stark black background with only a logo and text lacks the dynamic, energetic, and aspirational mood typically associated with Nike's visual brand tone.)."
#     },
#     {
#       "frame_index": 290,
#       "timing": "00:00:11",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The image is almost entirely black with no discernible product, subject, or lighting. Visual quality is extremely poor.). Tone: 0.00 (Mismatch: The frame is completely black and devoid of any content, thus it cannot convey any brand tone or mood associated with Nike.)."
#     },
#     {
#       "frame_index": 227,
#       "timing": "00:00:09",
#       "metric_failed": "Logo / Quality",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (No Nike product is visible in the frame, making it impossible to evaluate the visual quality of a product focus area.)."
#     },
#     {
#       "frame_index": 291,
#       "timing": "00:00:11",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (ABSENT). Quality: 0.20 (The entire frame is black, with no visible product or content, thus visual quality cannot be assessed beyond being completely dark and featureless.). Tone: 0.00 (Mismatch: The frame is completely black and conveys no mood, composition, or color grading relevant to Nike's dynamic and performance-oriented brand tone.)."
#     },
#     {
#       "frame_index": 297,
#       "timing": "00:00:11",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The frame is almost entirely black, making it impossible to discern any product or details. The small visible reddish area does not contain any recognizable content.). Tone: 0.00 (Mismatch: The completely dark and empty frame does not convey Nike's typical energetic, performance-driven, and clear brand aesthetic.)."
#     },
#     {
#       "frame_index": 301,
#       "timing": "00:00:12",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The image is almost entirely black and featureless; no product is visible, rendering clarity, sharpness, and lighting unassessable beyond 'very poor'.). Tone: 0.00 (Mismatch: The completely dark and featureless frame does not align with Nike's active, dynamic, and inspirational brand tone.)."
#     },
#     {
#       "frame_index": 295,
#       "timing": "00:00:11",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (ABSENT). Quality: 0.20 (The frame is almost entirely black, rendering any potential product or visual element completely obscured and unviewable.). Tone: 0.00 (Mismatch: The overwhelming darkness of the frame lacks any visual elements or mood consistent with Nike's active, dynamic, and inspiring brand tone.)."
#     },
#     {
#       "frame_index": 306,
#       "timing": "00:00:12",
#       "metric_failed": "Logo / Quality / Tone",
#       "reason_and_score": "Logo: 0.00 (NO). Quality: 0.20 (The image is almost entirely black, rendering any potential product completely indiscernible. There is no clarity, sharpness, or acceptable lighting.). Tone: 0.00 (Mismatch: The extreme darkness and lack of any discernible content or context do not align with Nike's active, inspiring, and clear brand aesthetic.)."
#     }
#   ]
# }
# {
#   "analyse_globale_synthetique": {
#     "score_final": 0.64,
#     "evaluation": "Fair (Needs review, moderate issues).",
#     "qualite_visuelle_score": 0.55,
#     "coherence_ton_score": 0.74
#   },
#   "problemes_majeurs_agreges": [
#     {
#       "type_probleme": "Qualité Extrême (Flou Pixelisation)",
#       "description": "Flou de mouvement sévère, pixelisation, ou manque de netteté sur le produit (Qualité score ≤ 0.40).",
#       "nombre_d_occurrences": 95,
#       "timings_affectes_uniques": [
#         "00:00:00",
#         "00:00:01",
#         "00:00:02",
#         "00:00:03",
#         "00:00:04",
#         "00:00:05",
#         "00:00:06",
#         "00:00:07",
#         "00:00:08",
#         "00:00:09",
#         "00:00:10",
#         "00:00:11",
#         "00:00:12"
#       ]
#     },
#     {
#       "type_probleme": "Conflit Marque / Ton Inadapté",
#       "description": "Présence de logos concurrents, ton abstrait, sombre ou amateur (Score Ton 0.00).",
#       "nombre_d_occurrences": 13,
#       "timings_affectes_uniques": [
#         "00:00:00",
#         "00:00:03",
#         "00:00:05",
#         "00:00:06",
#         "00:00:09",
#         "00:00:10",
#         "00:00:11"
#       ]
#     },
#     {
#       "type_probleme": "Visibilité Logo Faible (Absence)",
#       "description": "Logo non visible (Logo score 0.00) dans un contexte où la qualité est acceptable.",
#       "nombre_d_occurrences": 11,
#       "timings_affectes_uniques": [
#         "00:00:00",
#         "00:00:01",
#         "00:00:02",
#         "00:00:03",
#         "00:00:05",
#         "00:00:09"
#       ]
#     }
#   ]
# }
